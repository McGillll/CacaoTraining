# %% [markdown]
# <a href="https://colab.research.google.com/github/McGillll/CacaoTraining/blob/main/Train_YOLO_Models.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Train YOLO Models in Google Colab
# **Author:** Evan Juras, [EJ Technology Consultants](https://ejtech.io)
#
# **Last updated:** January 3, 2025
#
# **GitHub:** [Train and Deploy YOLO Models](https://github.com/EdjeElectronics/Train-and-Deploy-YOLO-Models)
#
# # Introduction
#
# This notebook uses [Ultralytics](https://docs.ultralytics.com/) to train YOLO11, YOLOv8, or YOLOv5 object detection models with a custom dataset. At the end of this Colab, you'll have a custom YOLO model that you can run on your PC, phone, or edge device like the Raspberry Pi.
#
# <p align=center>
# <img src="https://s3.us-west-1.amazonaws.com/evanjuras.com/img/yolo-model-demo.gif" height="360"><br>
# <i>Custom YOLO candy detection model in action!</i>
# </p>
#
# I created a YouTube video that walks through this guide step by step. I recommend following along with the video while working through this notebook.
#
# <p align=center>
# <a href="https://youtu.be/r0RspiLG260" target="_blank"><img src="https://raw.githubusercontent.com/EdjeElectronics/Train-and-Deploy-YOLO-Models/refs/heads/main/doc/Train_YOLO_Thumbnail2.png" height="240"><br>
# <i>Click here to go to the video!</i></a>
# </p>
#
# **Important note: This notebook will be continuously updated to make sure it works with newer versions of Ultralytics and YOLO. If you see any differences between the YouTube video and this notebook, always follow the notebook!**
#
# ### Working in Colab
# Colab provides a virtual machine in your browser complete with a Linux OS, filesystem, Python environment, and best of all, a free GPU. We'll install PyTorch and Ultralytics in this environment and use it to train our model. Simply click the Play button on sections of code in this notebook to execute them on the virtual machine.
#
# ### Navigation
# To navigate this notebook, use the table of contents in the left sidebar to jump from section to section.

# %% [markdown]
# **Verify NVIDIA GPU Availability**
#
# Make sure you're using a GPU-equipped machine by going to "Runtime" -> "Change runtime type" in the top menu bar, and then selecting one of the GPU options in the Hardware accelerator section. Click Play on the following code block to verify that the NVIDIA GPU is present and ready for training.

# %%
# !nvidia-smi

# %% [markdown]
# #1.&nbsp;Gather and Label Training Images

# %% [markdown]
# Before we start training, we need to gather and label images that will be used for training the object detection model. A good starting point for a proof-of-concept model is 200 images. The training images should have random objects in the image along with the desired objects, and should have a variety of backgrounds and lighting conditions.
#
# There are a couple options for gathering images:
#
#
# *   Build a custom dataset by taking your own pictures of the objects and labeling them (this typically results in the best performance)
# *   Find a pre-made dataset from sources like [Roboflow Universe](), [Kaggle](), or [Google Images V7]()
#
#
# If you want to build your own dataset, there are several tools available for labeling images. One good option is [Label Studio](https://labelstud.io/?utm_source=youtube&utm_medium=video&utm_campaign=edjeelectronics), a free and open-source labeling tool that has a simple workflow while providing capabilities for more advanced features. My YouTube video that walks through this notebook (link to be added soon) shows how to label images with Label Studio.
#
# <p align=center>
# <img src="https://raw.githubusercontent.com/EdjeElectronics/Train-and-Deploy-YOLO-Models/refs/heads/main/doc/label-studio-example.PNG" height="380"><br>
# <i>Example of a candy image labeled with Label Studio.</i>
# </p>
#
# If you used Label Studio to label and export the images, they'll be exported in a `project.zip` file that contains the following:
#
# - An `images` folder containing the images
# - A `labels` folder containing the labels in YOLO annotation format
# - A `classes.txt` labelmap file that contains all the classes
# - A `notes.json` file that contains info specific to Label Studio (this file can be ignored)
#
# If you obtained your dataset from another source (like Roboflow Universe) or used another tool to label your dataset, make sure the files are organized in the same folder structure.
#
# <p align=center>
# <img src="https://raw.githubusercontent.com/EdjeElectronics/Train-and-Deploy-YOLO-Models/refs/heads/main/doc/zipped-data-example.png" height=""><br>
# <i>Organize your data in the folders shown here. See my <a href="https://s3.us-west-1.amazonaws.com/evanjuras.com/resources/candy_data_06JAN25.zip">Candy Detection Dataset</a> for an example.</i>
# </p>
#
# Once you've got your dataset built, put into the file structure shown above, and zipped into `data.zip`, you're ready to move on to the next step.

# %% [markdown]
# # 2.&nbsp;Upload Image Dataset and Prepare Training Data

# %% [markdown]
# Next, we'll upload our dataset and prepare it for training with YOLO. We'll split the dataset into train and validation folders, and we'll automatically generate the configuration file for training the model.

# %% [markdown]
# ## 2.1 Upload images
#
# First, we need to upload the dataset to Colab. Here are a few options for moving the `data.zip` folder into this Colab instance.

# %% [markdown]
# **Option 1. Upload through Google Colab**
#
# Upload the `data.zip` file to the Google Colab instance by clicking the "Files" icon on the left hand side of the browser, and then the "Upload to session storage" icon. Select the zip folder to upload it.
#
# <p>
# <br>
# <img src="https://raw.githubusercontent.com/EdjeElectronics/Train-and-Deploy-YOLO-Models/refs/heads/main/doc/upload-colab-files.png" height="240">
# </p>

# %% [markdown]
# **Option 2. Copy from Google Drive**
#
# You can also upload your images to your personal Google Drive, mount the drive on this Colab session, and copy them over to the Colab filesystem. This option works well if you want to upload the images beforehand so you don't have to wait for them to upload each time you restart this Colab. If you have more than 50MB worth of images, I recommend using this option.
#
# First, upload the `data.zip` file to your Google Drive, and make note of the folder you uploaded them to. Replace `MyDrive/path/to/data.zip` with the path to your zip file. (For example, I uploaded the zip file to folder called "candy-dataset1", so I would use `MyDrive/candy-dataset1/data.zip` for the path). Then, run the following block of code to mount your Google Drive to this Colab session and copy the folder to this filesystem.

# %%
from google.colab import drive
drive.mount('/content/gdrive')

# !cp /content/gdrive/MyDrive/path/to/data.zip /content

# %% [markdown]
# **Option 3. Use my candy detection or coin detection dataset**
#
# If you just want to test the process on a pre-made dataset, you can use one of my datasets:
#
# *   [Candy image dataset](https://s3.us-west-1.amazonaws.com/evanjuras.com/resources/candy_data_14DEC24.zip), which contains 162 pictures of popular candies (Skittles, Snickers, etc)
# *   [Coin image dataset](https://s3.us-west-1.amazonaws.com/evanjuras.com/resources/YOLO_coin_data_12DEC30.zip), which contains 750 pictures of US coins (pennies, dimes, nickels, and quarters)
#
# Download one of the datasets by running the following code block. I'll use the candy detection dataset as the example for the rest of the notebook.

# %%
# To use my one of pre-made dataset instead of your own custom dataset, download it here (control which dataset is downloaded by commenting out either line)
# !wget -O /content/data.zip https://s3.us-west-1.amazonaws.com/evanjuras.com/resources/candy_data_06JAN25.zip # Candy dataset
#!wget -O /content/data.zip https://s3.us-west-1.amazonaws.com/evanjuras.com/resources/YOLO_coin_data_12DEC30.zip # Coin dataset

# %% [markdown]
# ## 2.2 Split images into train and validation folders

# %% [markdown]
# At this point, whether you used Option 1, 2, or 3, you should be able to click the folder icon on the left and see your `data.zip` file in the list of files. Next, we'll unzip `data.zip` and create some folders to hold the images. Run the following code block to unzip the data.

# %%
# Unzip images to a custom data folder
# !unzip -q /content/data.zip -d /content/custom_data

# %% [markdown]
# Ultralytics requires a particular folder structure to store training data for models. Ultralytics requires a particular folder structure to store training data for models. The root folder is named “data”. Inside, there are two main folders:
#
# *   **Train**: These are the actual images used to train the model. In one epoch of training, every image in the train set is passed into the neural network. The training algorithm adjusts the network weights to fit the data in the images.
#
#
# *   **Validation**: These images are used to check the model's performance at the end of each training epoch.
#
# In each of these folders is a “images” folder and a “labels” folder, which hold the image files and annotation files respectively.

# %% [markdown]
# I wrote a Python script that will automatically create the required folder structure and randomly move 90% of dataset to the "train" folder and 10% to the "validation" folder. Run the following code block to download and execute the scrpt.

# %%
# !wget -O /content/train_val_split.py https://raw.githubusercontent.com/EdjeElectronics/Train-and-Deploy-YOLO-Models/refs/heads/main/utils/train_val_split.py

# TO DO: Improve robustness of train_val_split.py script so it can handle nested data folders, etc
# !python train_val_split.py --datapath="/content/custom_data" --train_pct=0.9
# Out:
# --2025-09-25 12:12:32--  https://raw.githubusercontent.com/EdjeElectronics/Train-and-Deploy-YOLO-Models/refs/heads/main/utils/train_val_split.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3203 (3.1K) [text/plain]
# Saving to: ‘/content/train_val_split.py’
#
# /content/train_val_ 100%[===================>]   3.13K  --.-KB/s    in 0s
#
# 2025-09-25 12:12:32 (40.5 MB/s) - ‘/content/train_val_split.py’ saved [3203/3203]
#
# Created folder at /content/data/train/images.
# Created folder at /content/data/train/labels.
# Created folder at /content/data/validation/images.
# Created folder at /content/data/validation/labels.
# Number of image files: 3020
# Number of annotation files: 3020
# Images moving to train: 2718
# Images moving to validation: 302

# %% [markdown]
# # 3.&nbsp;Install Requirements (Ultralytics)
#
# Next, we'll install the Ultralytics library in this Google Colab instance. This Python library will be used to train the YOLO model.

# %%
# !pip install ultralytics
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.3.203-py3-none-any.whl.metadata (37 kB)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.0.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (4.12.0.88)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (11.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.32.4)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.16.2)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.8.0+cu126)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (0.23.0+cu126)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: polars in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.25.2)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics)
#   Downloading ultralytics_thop-2.0.17-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.60.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.2.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (2025.8.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.4.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)
# Downloading ultralytics-8.3.203-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 55.6 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.17-py3-none-any.whl (28 kB)
# Installing collected packages: ultralytics-thop, ultralytics
# Successfully installed ultralytics-8.3.203 ultralytics-thop-2.0.17

# %% [markdown]
# # 4.&nbsp;Configure Training

# %% [markdown]
# There's one last step before we can run training: we need to create the Ultralytics training configuration YAML file. This file specifies the location of your train and validation data, and it also defines the model's classes. An example configuration file model is available [here](https://github.com/ultralytics/ultralytics/blob/main/ultralytics/cfg/datasets/coco128.yaml).
#
# Run the code block below to automatically generate a `data.yaml` configuration file. Make sure you have a labelmap file located at `custom_data/classes.txt`. If you used Label Studio or one of my pre-made datasets, it should already be present. If you assembled the dataset another way, you may have to manually create the `classes.txt` file (see [here](https://github.com/EdjeElectronics/Train-and-Deploy-YOLO-Models/blob/main/doc/classes.txt) for an example of how it's formatted).

# %%
# Python function to automatically create data.yaml config file
# 1. Reads "classes.txt" file to get list of class names
# 2. Creates data dictionary with correct paths to folders, number of classes, and names of classes
# 3. Writes data in YAML format to data.yaml

import yaml
import os

def create_data_yaml(path_to_classes_txt, path_to_data_yaml):

  # Read class.txt to get class names
  if not os.path.exists(path_to_classes_txt):
    print(f'classes.txt file not found! Please create a classes.txt labelmap and move it to {path_to_classes_txt}')
    return
  with open(path_to_classes_txt, 'r') as f:
    classes = []
    for line in f.readlines():
      if len(line.strip()) == 0: continue
      classes.append(line.strip())
  number_of_classes = len(classes)

  # Create data dictionary
  data = {
      'path': '/content/data',
      'train': 'train/images',
      'val': 'validation/images',
      'nc': number_of_classes,
      'names': classes
  }

  # Write data to YAML file
  with open(path_to_data_yaml, 'w') as f:
    yaml.dump(data, f, sort_keys=False)
  print(f'Created config file at {path_to_data_yaml}')

  return

# Define path to classes.txt and run function
path_to_classes_txt = '/content/custom_data/classes.txt'
path_to_data_yaml = '/content/data.yaml'

create_data_yaml(path_to_classes_txt, path_to_data_yaml)

print('\nFile contents:\n')
# !cat /content/data.yaml
# Out:
# Created config file at /content/data.yaml
#
# File contents:
#
# path: /content/data
# train: train/images
# val: validation/images
# nc: 3
# names:
# - Blackpod rot
# - Frostypod rot
# - Healthy pod

# %% [markdown]
# # 5.&nbsp;Train Model

# %% [markdown]
# ## 5.1 Training Parameters
# Now that the data is organized and the config file is created, we're ready to start training! First, there are a few important parameters to decide on. Visit my article on [Training YOLO Models Locally](https://www.ejtech.io/learn/train-yolo-models) to learn more about these parameters and how to choose them.
#
# **Model architecture & size (`model`):**
#
# There are several YOLO11 models sizes available to train, including `yolo11n.pt`, `yolo11s.pt`, `yolo11m.pt`, `yolo11l.pt`, and `yolo11xl.pt`. Larger models run slower but have higher accuracy, while smaller models run faster but have lower accuracy. I made a brief YouTube video that compares performance of different YOLO models on a Raspberry Pi 5 and a laptop with a RTX 4050 GPU, [check it out here to get a sense of their speed accuracy](https://youtu.be/_WKS4E9SmkA). If you aren't sure which model size to use, `yolo11s.pt` is a good starting point.
#
# You can also train YOLOv8 or YOLOv5 models by substituting `yolo11` for `yolov8` or `yolov5`.
#
#
# **Number of epochs (`epochs`)**
#
# In machine learning, one “epoch” is one single pass through the full training dataset. Setting the number of epochs dictates how long the model will train for. The best amount of epochs to use depends on the size of the dataset and the model architecture. If your dataset has less than 200 images, a good starting point is 60 epochs. If your dataset has more than 200 images, a good starting point is 40 epochs.
#
#
# **Resolution (`imgsz`)**
#
# Resolution has a large impact on the speed and accuracy of the model: a lower resolution model will have higher speed but less accuracy. YOLO models are typically trained and inferenced at a 640x640 resolution. However, if you want your model to run faster or know you will be working with low-resolution images, try using a lower resolution like 480x480.

# %% [markdown]
# ## 5.2 Run Training!

# %% [markdown]
# Run the following code block to begin training. If you want to use a different model, number of epochs, or resolution, change `model`, `epochs`, or `imgsz`.

# %%
# !yolo detect train data=/content/data.yaml model=yolo11s.pt epochs=64 imgsz=640
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11s.pt to 'yolo11s.pt': 100% ━━━━━━━━━━━━ 18.4MB 259.5MB/s 0.1s
# Ultralytics 8.3.203 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/content/data.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=64, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11s.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=train, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/content/runs/detect/train, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 213.7MB/s 0.0s
# Overriding model.yaml nc=80 with nc=3
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   3                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   4                  -1  1    103360  ultralytics.nn.modules.block.C3k2            [128, 256, 1, False, 0.25]
#   5                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   6                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    443776  ultralytics.nn.modules.block.C3k2            [768, 256, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1    127680  ultralytics.nn.modules.block.C3k2            [512, 128, 1, False]
#  17                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1    345472  ultralytics.nn.modules.block.C3k2            [384, 256, 1, False]
#  20                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1   1511424  ultralytics.nn.modules.block.C3k2            [768, 512, 1, True]
#  23        [16, 19, 22]  1    820569  ultralytics.nn.modules.head.Detect           [3, [128, 256, 512]]
# YOLO11s summary: 181 layers, 9,428,953 parameters, 9,428,937 gradients, 21.6 GFLOPs
#
# Transferred 493/499 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt': 100% ━━━━━━━━━━━━ 5.4MB 275.7MB/s 0.0s
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1956.6±629.8 MB/s, size: 110.2 KB)
# train: Scanning /content/data/train/labels... 2718 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 2718/2718 1.8Kit/s 1.5s
# train: New cache created: /content/data/train/labels.cache
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 2061, len(boxes) = 8483. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 911.6±585.2 MB/s, size: 97.1 KB)
# val: Scanning /content/data/validation/labels... 302 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 302/302 1.6Kit/s 0.2s
# val: New cache created: /content/data/validation/labels.cache
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 282, len(boxes) = 1038. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
# Plotting labels to /content/runs/detect/train/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001429, momentum=0.9) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.0005), 87 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to /content/runs/detect/train
# Starting training for 64 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/64      4.08G      1.113      1.954      1.263         63        640: 100% ━━━━━━━━━━━━ 170/170 2.3it/s 1:14
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 1.0it/s 9.7s
#                    all        302       1038      0.432      0.523      0.398      0.271
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/64      4.88G      1.159      1.592      1.275         86        640: 100% ━━━━━━━━━━━━ 170/170 3.1it/s 55.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.7it/s 3.8s
#                    all        302       1038      0.172      0.253      0.122     0.0762
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/64      4.92G      1.177      1.581      1.295         70        640: 100% ━━━━━━━━━━━━ 170/170 3.1it/s 55.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 3.4it/s 3.0s
#                    all        302       1038      0.537      0.395       0.37      0.246
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/64      4.96G       1.16      1.557      1.285         72        640: 100% ━━━━━━━━━━━━ 170/170 3.1it/s 54.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.9it/s 3.5s
#                    all        302       1038      0.514      0.471      0.435      0.308
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/64      4.99G      1.116      1.473      1.255         77        640: 100% ━━━━━━━━━━━━ 170/170 3.1it/s 54.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 3.3it/s 3.0s
#                    all        302       1038      0.558      0.424      0.401      0.287
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/64      5.04G      1.113      1.444      1.245         56        640: 100% ━━━━━━━━━━━━ 170/170 3.1it/s 54.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 3.4it/s 2.9s
#                    all        302       1038      0.618      0.533      0.508      0.366
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/64      5.07G      1.054      1.376      1.214         64        640: 100% ━━━━━━━━━━━━ 170/170 3.1it/s 54.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 3.2it/s 3.2s
#                    all        302       1038      0.508      0.483      0.472       0.36
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/64      5.12G      1.073      1.367      1.231         53        640: 100% ━━━━━━━━━━━━ 170/170 3.1it/s 54.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 3.4it/s 2.9s
#                    all        302       1038      0.606      0.536      0.499      0.377
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/64      5.15G      1.038      1.343      1.206         55        640: 100% ━━━━━━━━━━━━ 170/170 3.1it/s 54.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.8it/s 3.5s
#                    all        302       1038      0.541      0.527      0.495      0.373
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/64       5.2G      1.035      1.317      1.214        101        640: 100% ━━━━━━━━━━━━ 170/170 3.1it/s 54.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 3.4it/s 2.9s
#                    all        302       1038      0.625      0.595      0.578      0.444
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/64      5.23G          1      1.278      1.185         91        640: 100% ━━━━━━━━━━━━ 170/170 3.1it/s 54.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.7it/s 3.7s
#                    all        302       1038      0.647      0.539      0.576      0.442
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/64      5.27G      1.015        1.3      1.198         91        640: 100% ━━━━━━━━━━━━ 170/170 3.1it/s 54.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 3.2it/s 3.1s
#                    all        302       1038      0.568      0.547      0.527      0.412
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/64      5.31G     0.9908      1.271       1.18         72        640: 100% ━━━━━━━━━━━━ 170/170 3.1it/s 54.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 3.0it/s 3.3s
#                    all        302       1038      0.649      0.562      0.585      0.451
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/64      5.35G     0.9922      1.258      1.179         98        640: 100% ━━━━━━━━━━━━ 170/170 3.1it/s 54.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 3.5it/s 2.9s
#                    all        302       1038      0.665      0.596      0.605      0.467
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/64      5.39G     0.9723      1.213      1.168         63        640: 100% ━━━━━━━━━━━━ 170/170 3.1it/s 54.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 3.4it/s 2.9s
#                    all        302       1038      0.622      0.586      0.586      0.459
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/64      5.43G     0.9608      1.201      1.155         84        640: 100% ━━━━━━━━━━━━ 170/170 3.1it/s 54.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 3.3it/s 3.0s
#                    all        302       1038      0.674      0.576      0.588      0.447
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/64      5.47G     0.9549      1.199      1.158         60        640: 100% ━━━━━━━━━━━━ 170/170 3.1it/s 54.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 3.4it/s 2.9s
#                    all        302       1038      0.656       0.58      0.627      0.484
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/64      5.51G     0.9439      1.173      1.147         62        640: 100% ━━━━━━━━━━━━ 170/170 3.1it/s 54.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 3.4it/s 2.9s
#                    all        302       1038      0.577      0.639      0.595      0.477
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/64      5.55G      0.931       1.16      1.146         60        640: 100% ━━━━━━━━━━━━ 170/170 3.1it/s 54.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 3.3it/s 3.1s
#                    all        302       1038      0.718      0.599      0.615      0.485
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/64      5.59G     0.9342      1.134      1.142         73        640: 100% ━━━━━━━━━━━━ 170/170 3.1it/s 54.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 3.5it/s 2.9s
#                    all        302       1038      0.689      0.654      0.649      0.514
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/64      5.63G     0.9405      1.129      1.138         80        640: 100% ━━━━━━━━━━━━ 170/170 3.1it/s 54.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 3.2it/s 3.1s
#                    all        302       1038      0.743      0.601      0.641      0.504
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/64      5.67G     0.9206      1.135      1.138         51        640: 100% ━━━━━━━━━━━━ 170/170 3.1it/s 54.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 3.5it/s 2.9s
#                    all        302       1038      0.685      0.643      0.656      0.519
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/64      5.71G     0.9054       1.11      1.129         65        640: 100% ━━━━━━━━━━━━ 170/170 3.1it/s 54.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 3.2it/s 3.1s
#                    all        302       1038      0.686      0.603      0.641      0.508
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/64      5.75G     0.9122      1.126      1.132         66        640: 100% ━━━━━━━━━━━━ 170/170 3.1it/s 54.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 3.4it/s 2.9s
#                    all        302       1038      0.669       0.66      0.661      0.525
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/64      5.79G     0.8999      1.103       1.13        104        640: 100% ━━━━━━━━━━━━ 170/170 3.1it/s 54.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 3.1it/s 3.2s
#                    all        302       1038      0.711      0.624      0.651      0.531
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/64      5.83G      0.903      1.097      1.128        103        640: 100% ━━━━━━━━━━━━ 170/170 3.1it/s 54.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 3.5it/s 2.9s
#                    all        302       1038      0.729      0.627      0.651      0.518
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/64      5.87G      0.873      1.074      1.109         80        640: 100% ━━━━━━━━━━━━ 170/170 3.1it/s 54.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 3.1it/s 3.2s
#                    all        302       1038      0.684      0.646      0.658      0.534
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/64      5.91G      0.887      1.057      1.121         64        640: 100% ━━━━━━━━━━━━ 170/170 3.2it/s 53.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 3.4it/s 2.9s
#                    all        302       1038      0.719      0.644      0.661       0.53
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/64      5.95G     0.8804      1.057      1.111         68        640: 100% ━━━━━━━━━━━━ 170/170 3.1it/s 55.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.8it/s 3.5s
#                    all        302       1038      0.689      0.602      0.636      0.509
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/64      5.99G     0.8615      1.016      1.094         85        640: 100% ━━━━━━━━━━━━ 170/170 3.1it/s 55.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 3.3it/s 3.0s
#                    all        302       1038      0.707       0.66      0.675      0.543
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       31/64      6.03G     0.8604       1.04      1.106         72        640: 100% ━━━━━━━━━━━━ 170/170 3.1it/s 55.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.8it/s 3.6s
#                    all        302       1038      0.724       0.64      0.676      0.548
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       32/64      6.07G     0.8713      1.048       1.11         74        640: 100% ━━━━━━━━━━━━ 170/170 3.1it/s 54.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 3.5it/s 2.8s
#                    all        302       1038      0.656      0.673       0.67      0.541
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       33/64      6.11G     0.8643      1.037      1.102         47        640: 100% ━━━━━━━━━━━━ 170/170 3.1it/s 54.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.9it/s 3.5s
#                    all        302       1038      0.704       0.67      0.681      0.549
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       34/64      6.15G     0.8604      1.012      1.104         53        640: 100% ━━━━━━━━━━━━ 170/170 3.1it/s 54.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 3.5it/s 2.9s
#                    all        302       1038      0.692       0.67      0.688      0.554
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       35/64      6.19G     0.8471          1      1.096         56        640: 100% ━━━━━━━━━━━━ 170/170 3.1it/s 55.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 3.3it/s 3.1s
#                    all        302       1038      0.682      0.691      0.701      0.576
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       36/64      6.23G     0.8384          1      1.094         64        640: 100% ━━━━━━━━━━━━ 170/170 3.1it/s 54.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 3.5it/s 2.9s
#                    all        302       1038      0.718      0.658      0.676      0.551
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       37/64      6.27G     0.8343     0.9867      1.095         61        640: 100% ━━━━━━━━━━━━ 170/170 3.1it/s 55.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 3.4it/s 2.9s
#                    all        302       1038        0.7      0.675      0.681      0.556
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       38/64      6.31G     0.8202     0.9772      1.077         61        640: 100% ━━━━━━━━━━━━ 170/170 3.1it/s 54.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 3.2it/s 3.2s
#                    all        302       1038      0.727      0.674      0.689       0.56
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       39/64      6.35G     0.8212     0.9653      1.081        119        640: 100% ━━━━━━━━━━━━ 170/170 3.1it/s 55.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 3.3it/s 3.0s
#                    all        302       1038      0.748      0.676      0.708      0.573
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       40/64      6.39G     0.8483      1.013      1.096         65        640: 100% ━━━━━━━━━━━━ 170/170 3.1it/s 54.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 3.0it/s 3.4s
#                    all        302       1038       0.73      0.665      0.702      0.566
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       41/64      6.43G     0.8204     0.9732      1.081         74        640: 100% ━━━━━━━━━━━━ 170/170 3.1it/s 54.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 3.5it/s 2.9s
#                    all        302       1038       0.74      0.672      0.709      0.584
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       42/64      6.47G     0.8171     0.9468      1.084        100        640: 100% ━━━━━━━━━━━━ 170/170 3.1it/s 54.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.7it/s 3.6s
#                    all        302       1038       0.74       0.68       0.71      0.586
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       43/64      6.51G     0.8084     0.9348      1.077         52        640: 100% ━━━━━━━━━━━━ 170/170 3.1it/s 54.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 3.4it/s 3.0s
#                    all        302       1038      0.708      0.702      0.704      0.577
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       44/64      6.55G     0.8077     0.9347      1.076         60        640: 100% ━━━━━━━━━━━━ 170/170 3.1it/s 54.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.8it/s 3.6s
#                    all        302       1038      0.723      0.682      0.705      0.578
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       45/64      6.59G     0.7959     0.9327      1.072         53        640: 100% ━━━━━━━━━━━━ 170/170 3.1it/s 54.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 3.5it/s 2.8s
#                    all        302       1038      0.707      0.693      0.705      0.574
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       46/64      6.63G     0.8111     0.9447      1.085         67        640: 100% ━━━━━━━━━━━━ 170/170 3.1it/s 54.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.8it/s 3.5s
#                    all        302       1038      0.759      0.659      0.713      0.585
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       47/64      6.67G     0.7812     0.8984      1.059         74        640: 100% ━━━━━━━━━━━━ 170/170 3.1it/s 54.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 3.5it/s 2.9s
#                    all        302       1038      0.768      0.669      0.716      0.589
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       48/64      6.71G     0.7939     0.9021      1.065         69        640: 100% ━━━━━━━━━━━━ 170/170 3.1it/s 54.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.9it/s 3.5s
#                    all        302       1038      0.726      0.707      0.725      0.604
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       49/64      6.75G     0.7749     0.8987       1.06         69        640: 100% ━━━━━━━━━━━━ 170/170 3.1it/s 54.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 3.5it/s 2.9s
#                    all        302       1038      0.725      0.679      0.719      0.595
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       50/64      6.79G     0.7689      0.893      1.054         60        640: 100% ━━━━━━━━━━━━ 170/170 3.1it/s 54.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 3.1it/s 3.2s
#                    all        302       1038      0.756      0.696      0.729        0.6
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       51/64      6.82G     0.7645     0.8687      1.055         87        640: 100% ━━━━━━━━━━━━ 170/170 3.1it/s 54.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 3.5it/s 2.9s
#                    all        302       1038      0.727      0.693       0.72      0.596
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       52/64      6.87G      0.775     0.8656      1.054        110        640: 100% ━━━━━━━━━━━━ 170/170 3.1it/s 55.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 3.3it/s 3.1s
#                    all        302       1038      0.741      0.715      0.724      0.606
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       53/64       6.9G     0.7598     0.8701      1.048         81        640: 100% ━━━━━━━━━━━━ 170/170 3.1it/s 54.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 3.3it/s 3.0s
#                    all        302       1038      0.729      0.694      0.721      0.594
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       54/64      6.95G     0.7711     0.8734      1.054        105        640: 100% ━━━━━━━━━━━━ 170/170 3.1it/s 55.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 3.3it/s 3.0s
#                    all        302       1038      0.732      0.713      0.725        0.6
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       55/64      6.99G     0.7106     0.7871      1.002         43        640: 100% ━━━━━━━━━━━━ 170/170 3.1it/s 55.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 3.1it/s 3.2s
#                    all        302       1038       0.73      0.701      0.721      0.597
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       56/64      7.03G      0.695     0.7475      0.997         46        640: 100% ━━━━━━━━━━━━ 170/170 3.2it/s 53.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 3.5it/s 2.9s
#                    all        302       1038      0.721      0.704      0.728      0.614
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       57/64      7.06G     0.6858     0.7328     0.9927         43        640: 100% ━━━━━━━━━━━━ 170/170 3.2it/s 53.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 3.5it/s 2.9s
#                    all        302       1038       0.75      0.691      0.738      0.621
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       58/64      7.11G     0.6734      0.711     0.9864         38        640: 100% ━━━━━━━━━━━━ 170/170 3.2it/s 53.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 3.2it/s 3.1s
#                    all        302       1038      0.721      0.724      0.732      0.617
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       59/64      7.14G     0.6689     0.7044     0.9786         35        640: 100% ━━━━━━━━━━━━ 170/170 3.2it/s 53.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 3.5it/s 2.8s
#                    all        302       1038      0.743      0.696      0.735      0.612
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       60/64      7.19G     0.6666     0.6922     0.9783         32        640: 100% ━━━━━━━━━━━━ 170/170 3.2it/s 53.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.8it/s 3.6s
#                    all        302       1038      0.739      0.699      0.735      0.623
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       61/64      7.22G      0.656     0.6887     0.9778         33        640: 100% ━━━━━━━━━━━━ 170/170 3.2it/s 53.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 3.5it/s 2.9s
#                    all        302       1038      0.753      0.686      0.735      0.614
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       62/64      7.27G     0.6545     0.6635     0.9759         50        640: 100% ━━━━━━━━━━━━ 170/170 3.2it/s 53.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.8it/s 3.6s
#                    all        302       1038      0.765      0.679      0.726      0.613
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       63/64       7.3G     0.6597     0.6728     0.9783         52        640: 100% ━━━━━━━━━━━━ 170/170 3.2it/s 53.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 3.4it/s 3.0s
#                    all        302       1038      0.783      0.667       0.73      0.614
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       64/64      7.34G     0.6462     0.6548     0.9748         45        640: 100% ━━━━━━━━━━━━ 170/170 3.2it/s 53.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 3.2it/s 3.1s
#                    all        302       1038      0.774      0.681      0.737      0.619
#
# 64 epochs completed in 1.042 hours.
# Optimizer stripped from /content/runs/detect/train/weights/last.pt, 19.2MB
# Optimizer stripped from /content/runs/detect/train/weights/best.pt, 19.2MB
#
# Validating /content/runs/detect/train/weights/best.pt...
# Ultralytics 8.3.203 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11s summary (fused): 100 layers, 9,413,961 parameters, 0 gradients, 21.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.1it/s 4.8s
#                    all        302       1038      0.733      0.706      0.735      0.623
#           Blackpod rot        127        182      0.716      0.703      0.736      0.647
#          Frostypod rot         71         82      0.807      0.763      0.783      0.686
#            Healthy pod        241        774      0.676       0.65      0.687      0.535
# Speed: 0.2ms preprocess, 4.8ms inference, 0.0ms loss, 3.7ms postprocess per image
# Results saved to /content/runs/detect/train
# 💡 Learn more at https://docs.ultralytics.com/modes/train

# %% [markdown]
# The training algorithm will parse the images in the training and validation directories and then start training the model. At the end of each training epoch, the program runs the model on the validation dataset and reports the resulting mAP, precision, and recall. As training continues, the mAP should generally increase with each epoch. Training will end once it goes through the number of epochs specified by `epochs`.
#
# > **NOTE:** Make sure to allow training to run to completion, because an optimizer runs at the end of training that strips out unneeded layers from the model.
#
# The best trained model weights will be saved in `content/runs/detect/train/weights/best.pt`. Additional information about training is saved in the `content/runs/detect/train` folder, including a `results.png` file that shows how loss, precision, recall, and mAP progressed over each epoch.

# %% [markdown]
# #6.&nbsp;Test Model

# %% [markdown]
# The model has been trained; now it's time to test it! The commands below run the model on the images in the validation folder and then display the results for the first 10 images. This is a good way to confirm your model is working as expected. Click Play on the blocks below to see how your model performs.

# %%
# !yolo detect predict model=runs/detect/train/weights/best.pt source=data/validation/images save=True
# Out:
# Ultralytics 8.3.203 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11s summary (fused): 100 layers, 9,413,961 parameters, 0 gradients, 21.3 GFLOPs
#
# image 1/302 /content/data/validation/images/10_0_Fito_18_jpg.rf.f6c09445202ff6a64b867025b6a4b876.jpg: 640x640 2 Blackpod rots, 1 Healthy pod, 15.6ms
# image 2/302 /content/data/validation/images/10_2_Monilia_7_jpg.rf.73feba62a94271a6f127ce8c65957f20.jpg: 640x640 1 Frostypod rot, 15.6ms
# image 3/302 /content/data/validation/images/15_0_Monilia_26_jpg.rf.bda576d8721499e655f3dadda61e1e47.jpg: 640x640 1 Frostypod rot, 15.5ms
# image 4/302 /content/data/validation/images/19_2_Monilia_15_jpg.rf.59b089c3f24d1458750085ebb840bc59.jpg: 640x640 1 Frostypod rot, 15.6ms
# image 5/302 /content/data/validation/images/20_2_Fito_249_jpg.rf.351650974428335bb3fa5cd30cd817c4.jpg: 640x640 3 Blackpod rots, 1 Healthy pod, 15.5ms
# image 6/302 /content/data/validation/images/23_2_Monilia_19_jpg.rf.37cbdef48da4a4f50d2a142c03d55a71.jpg: 640x640 1 Blackpod rot, 2 Frostypod rots, 15.6ms
# image 7/302 /content/data/validation/images/28_2_Fito_43_jpg.rf.d193919a5cfdf98d3db17f9041e231e4.jpg: 640x640 1 Blackpod rot, 38.8ms
# image 8/302 /content/data/validation/images/30_2_Monilia_29_jpg.rf.38ec45b7bb74043fb5f96a4a24fb34ef.jpg: 640x640 1 Frostypod rot, 1 Healthy pod, 22.5ms
# image 9/302 /content/data/validation/images/37_2_Monilia_37_jpg.rf.02fd47066d1fa4c9fb54aa6bda61fea2.jpg: 640x640 1 Frostypod rot, 15.5ms
# image 10/302 /content/data/validation/images/38_2_Monilia_38_jpg.rf.6f4394a2d8c84d5020c0d9696161ae70.jpg: 640x640 1 Frostypod rot, 15.5ms
# image 11/302 /content/data/validation/images/3_2_Fito_123_jpg.rf.89893e61053ac651c9ea1919b952fd57.jpg: 640x640 1 Blackpod rot, 1 Healthy pod, 15.5ms
# image 12/302 /content/data/validation/images/3_2_Monilia_1_jpg.rf.d51770994fad531ed1adaba006881843.jpg: 640x640 2 Healthy pods, 15.5ms
# image 13/302 /content/data/validation/images/41_1_Monilia_41_jpg.rf.916112fc101eafef6ea57fa75d84ed30.jpg: 640x640 1 Frostypod rot, 15.5ms
# image 14/302 /content/data/validation/images/42_1_Monilia_42_jpg.rf.406973f71bd0a05268282a155575a6ee.jpg: 640x640 1 Frostypod rot, 15.6ms
# image 15/302 /content/data/validation/images/43_2_Monilia_43_jpg.rf.6ccbda251bc4f6d895f2865480931044.jpg: 640x640 1 Frostypod rot, 15.6ms
# image 16/302 /content/data/validation/images/45_0_Monilia_45_jpg.rf.d6058524d329472766f427fa7d5710fa.jpg: 640x640 2 Blackpod rots, 1 Healthy pod, 15.6ms
# image 17/302 /content/data/validation/images/47_0_Monilia_47_jpg.rf.6bc8e34144b481777e72cb24b3457443.jpg: 640x640 1 Frostypod rot, 15.5ms
# image 18/302 /content/data/validation/images/49_2_Monilia_49_jpg.rf.7409d530803ae834b12c649ff6a7bac1.jpg: 640x640 1 Blackpod rot, 1 Frostypod rot, 11.0ms
# image 19/302 /content/data/validation/images/53_0_Monilia_53_jpg.rf.491d7b11f881df81b1ac4a8f29807c40.jpg: 640x640 1 Frostypod rot, 1 Healthy pod, 10.5ms
# image 20/302 /content/data/validation/images/58_2_Monilia_58_jpg.rf.828877b1f1693d8f2e6a3aa4659bd266.jpg: 640x640 2 Frostypod rots, 10.5ms
# image 21/302 /content/data/validation/images/59_0_Monilia_59_jpg.rf.124703826b568086f4a0cab67ccf9e5b.jpg: 640x640 1 Frostypod rot, 10.5ms
# image 22/302 /content/data/validation/images/61_0_Monilia_61_jpg.rf.e91c4763b678177bb599f28b74d8c96e.jpg: 640x640 1 Frostypod rot, 10.5ms
# image 23/302 /content/data/validation/images/62_0_Monilia_62_jpg.rf.3df8de32f0fda4a1e108a0dd5dbaf347.jpg: 640x640 1 Frostypod rot, 1 Healthy pod, 10.5ms
# image 24/302 /content/data/validation/images/6_0_Monilia_4_jpg.rf.060b9e511e6e4464af5675b2780028fa.jpg: 640x640 1 Frostypod rot, 10.5ms
# image 25/302 /content/data/validation/images/6_2_Monilia_4_jpg.rf.ec85808795525b19d905225f3c1bf263.jpg: 640x640 1 Frostypod rot, 10.5ms
# image 26/302 /content/data/validation/images/74_0_Monilia_74_jpg.rf.faa1ee0c1cddd5759bac7d24f44d45da.jpg: 640x640 1 Frostypod rot, 10.5ms
# image 27/302 /content/data/validation/images/74_2_Monilia_74_jpg.rf.546da36d9abda594d5c7da81f1980d8a.jpg: 640x640 1 Blackpod rot, 1 Frostypod rot, 10.5ms
# image 28/302 /content/data/validation/images/7_0_Monilia_6_jpg.rf.45c526d473fa91893927f95b96f8a894.jpg: 640x640 2 Frostypod rots, 10.5ms
# image 29/302 /content/data/validation/images/8_2_Monilia_10_jpg.rf.fe24f90dc1b0514742449806b3a5a5aa.jpg: 640x640 1 Frostypod rot, 8.1ms
# image 30/302 /content/data/validation/images/9_1_Monilia_9_jpg.rf.9fbcb899345eb0d7f54649c65cadc65c.jpg: 640x640 2 Frostypod rots, 2 Healthy pods, 8.1ms
# image 31/302 /content/data/validation/images/CACAO-100-_jpg.rf.3f46a65f682203127fb8625e6e9fa651.jpg: 640x640 1 Healthy pod, 8.1ms
# image 32/302 /content/data/validation/images/CACAO-104-_jpg.rf.f15e6819aae33e2ab3b1c2c087995c24.jpg: 640x640 2 Blackpod rots, 3 Healthy pods, 8.1ms
# image 33/302 /content/data/validation/images/CACAO-107-_jpg.rf.25439e6d45bf9591d67504f363593eba.jpg: 640x640 1 Healthy pod, 8.1ms
# image 34/302 /content/data/validation/images/CACAO-11-_jpg.rf.2bf99068a8d01cabb5a73ccd158f1561.jpg: 640x640 2 Healthy pods, 8.1ms
# image 35/302 /content/data/validation/images/CACAO-12-_jpg.rf.291d2595d61f02890c2d4aee7ae5ea68.jpg: 640x640 5 Healthy pods, 8.0ms
# image 36/302 /content/data/validation/images/CACAO-127-_jpg.rf.280c360a13ab7555a49f49f5caeffe28.jpg: 640x640 1 Healthy pod, 20.5ms
# image 37/302 /content/data/validation/images/CACAO-131-_jpg.rf.00b1c89968660cedbff112243eac09d0.jpg: 640x640 1 Blackpod rot, 22.9ms
# image 38/302 /content/data/validation/images/CACAO-135-_jpg.rf.3d1df1aee696ee9b76cc26c82430f531.jpg: 640x640 1 Healthy pod, 23.7ms
# image 39/302 /content/data/validation/images/CACAO-137-_jpg.rf.49423ab6591813f20541efdb31f50b5e.jpg: 640x640 6 Healthy pods, 8.1ms
# image 40/302 /content/data/validation/images/CACAO-141-_jpg.rf.a3b0501c56f846a59934acaff678bfd5.jpg: 640x640 1 Healthy pod, 8.0ms
# image 41/302 /content/data/validation/images/CACAO-142-_jpg.rf.d2494c5c414f71db06c0f2f45149942a.jpg: 640x640 1 Healthy pod, 8.7ms
# image 42/302 /content/data/validation/images/CACAO-148-_jpg.rf.e979b29e41179f960c0cbbc166bbaa59.jpg: 640x640 1 Healthy pod, 8.0ms
# image 43/302 /content/data/validation/images/CACAO-154-_jpg.rf.0080e18673c641d5f9e980e3de569616.jpg: 640x640 1 Healthy pod, 8.1ms
# image 44/302 /content/data/validation/images/CACAO-163-_jpg.rf.362ec1ed56cd7db0c008e44d96f45e5f.jpg: 640x640 1 Healthy pod, 8.0ms
# image 45/302 /content/data/validation/images/CACAO-170-_jpg.rf.e32ffd46b56b55944af164a0d69c1ca9.jpg: 640x640 1 Blackpod rot, 2 Healthy pods, 8.0ms
# image 46/302 /content/data/validation/images/CACAO-173-_jpg.rf.7b87126a5be979842e2511d441f166eb.jpg: 640x640 2 Healthy pods, 8.0ms
# image 47/302 /content/data/validation/images/CACAO-177-_jpg.rf.2e66f87ec1653f6cf164c46ed47cf46d.jpg: 640x640 1 Blackpod rot, 1 Healthy pod, 8.1ms
# image 48/302 /content/data/validation/images/CACAO-182-_jpg.rf.03ad6ad5d3a6821d1463b547c768140d.jpg: 640x640 5 Healthy pods, 8.1ms
# image 49/302 /content/data/validation/images/CACAO-183-_jpg.rf.ac20933ab87ed84b77cf19ddd8f3daa0.jpg: 640x640 2 Healthy pods, 8.0ms
# image 50/302 /content/data/validation/images/CACAO-185-_jpg.rf.b7dbf7464a1b69852509e5ae2a294084.jpg: 640x640 1 Healthy pod, 8.0ms
# image 51/302 /content/data/validation/images/CACAO-194-_jpg.rf.3c1da0e19bff5252e8cb92a715589d33.jpg: 640x640 3 Healthy pods, 8.0ms
# image 52/302 /content/data/validation/images/CACAO-201-_jpg.rf.1c127db7ea68e31ff398e0b1736570f1.jpg: 640x640 1 Healthy pod, 8.5ms
# image 53/302 /content/data/validation/images/CACAO-214-_jpg.rf.16d653900bff6ac400db941cffdd70ed.jpg: 640x640 1 Blackpod rot, 1 Frostypod rot, 12.9ms
# image 54/302 /content/data/validation/images/CACAO-22-_jpg.rf.49571b3c7573b59c113ad04eec9b0c68.jpg: 640x640 2 Healthy pods, 11.3ms
# image 55/302 /content/data/validation/images/CACAO-237-_jpg.rf.6287df89348a9b207a5580a2ac749bc3.jpg: 640x640 2 Healthy pods, 8.0ms
# image 56/302 /content/data/validation/images/CACAO-244-_jpg.rf.c25a1f215b0da6871cc8fd8e8295cb99.jpg: 640x640 4 Healthy pods, 8.0ms
# image 57/302 /content/data/validation/images/CACAO-247-_jpg.rf.a81ca4ac6fed9443bf97e9143f469265.jpg: 640x640 3 Healthy pods, 9.4ms
# image 58/302 /content/data/validation/images/CACAO-248-_jpg.rf.d2b2ba72760aa4459e987bad32031350.jpg: 640x640 2 Healthy pods, 8.4ms
# image 59/302 /content/data/validation/images/CACAO-271-_jpg.rf.78d77efd3d4d90d65849f42531f38784.jpg: 640x640 1 Healthy pod, 7.6ms
# image 60/302 /content/data/validation/images/CACAO-273-_jpg.rf.cbd05f456febc903c76d3d534e7cf805.jpg: 640x640 3 Healthy pods, 7.7ms
# image 61/302 /content/data/validation/images/CACAO-283-_jpg.rf.9681ac67174dd3f489155665fc0cdad1.jpg: 640x640 1 Healthy pod, 7.6ms
# image 62/302 /content/data/validation/images/CACAO-285-_jpg.rf.a0f073265eb1912361b2a69ba733c230.jpg: 640x640 1 Blackpod rot, 7.6ms
# image 63/302 /content/data/validation/images/CACAO-290-_jpg.rf.0b4adfbffa01e35eaaaefc82a12b49b6.jpg: 640x640 4 Healthy pods, 9.6ms
# image 64/302 /content/data/validation/images/CACAO-300-_jpg.rf.93f49eec98f1a7c57c5afd3e09396c0e.jpg: 640x640 6 Healthy pods, 7.5ms
# image 65/302 /content/data/validation/images/CACAO-31-_jpg.rf.6072a83a283d78e910dd0d1f0ab3740e.jpg: 640x640 1 Blackpod rot, 1 Frostypod rot, 8.4ms
# image 66/302 /content/data/validation/images/CACAO-311-_jpg.rf.a86f7e93aa5ecb0c9d685940b0edeab9.jpg: 640x640 2 Healthy pods, 7.5ms
# image 67/302 /content/data/validation/images/CACAO-312-_jpg.rf.1a6561b00a55699e5412a930a7f4baa2.jpg: 640x640 2 Healthy pods, 7.5ms
# image 68/302 /content/data/validation/images/CACAO-322-_jpg.rf.f1363f1692722c0fe30098b6d97aff98.jpg: 640x640 5 Healthy pods, 7.7ms
# image 69/302 /content/data/validation/images/CACAO-330-_jpg.rf.ac6fa61efd3d653ead8588c014869e21.jpg: 640x640 3 Blackpod rots, 1 Healthy pod, 7.5ms
# image 70/302 /content/data/validation/images/CACAO-345-_jpg.rf.e64345728411bfc564006a8dfe535661.jpg: 640x640 4 Healthy pods, 7.4ms
# image 71/302 /content/data/validation/images/CACAO-368-_jpg.rf.ede1b23fe8503f6d66a1fe78108670a8.jpg: 640x640 3 Healthy pods, 7.4ms
# image 72/302 /content/data/validation/images/CACAO-369-_jpg.rf.0989f57b90149a80d7ada816bd1f54bb.jpg: 640x640 5 Healthy pods, 7.3ms
# image 73/302 /content/data/validation/images/CACAO-40-_jpg.rf.f2ece9c690837a6e8b28baee9409b77b.jpg: 640x640 1 Healthy pod, 7.5ms
# image 74/302 /content/data/validation/images/CACAO-43-_jpg.rf.ad8e15f8d10357a9b624249b1439f567.jpg: 640x640 2 Blackpod rots, 7.5ms
# image 75/302 /content/data/validation/images/CACAO-54-_jpg.rf.e3076c321226722323a6f49459bc5203.jpg: 640x640 1 Healthy pod, 7.6ms
# image 76/302 /content/data/validation/images/CACAO-56-_jpg.rf.3be02610d6af024c535fad60bdb2606b.jpg: 640x640 1 Blackpod rot, 2 Healthy pods, 7.5ms
# image 77/302 /content/data/validation/images/CACAO-81-_jpg.rf.9d393068a2503fa1d2d2dd96a3a2941d.jpg: 640x640 3 Healthy pods, 7.6ms
# image 78/302 /content/data/validation/images/CACAO-87-_jpg.rf.437905194102a8772f8ebbded6627f6f.jpg: 640x640 1 Blackpod rot, 2 Healthy pods, 7.4ms
# image 79/302 /content/data/validation/images/CACAO-88-_jpg.rf.cd56e5071e63192c920126d74e45fc13.jpg: 640x640 4 Healthy pods, 7.4ms
# image 80/302 /content/data/validation/images/CACAO-9-_jpg.rf.4d74a499cd51871271e87a3a50b30189.jpg: 640x640 1 Healthy pod, 7.5ms
# image 81/302 /content/data/validation/images/CACAO-90-_jpg.rf.e1dc03acb55461038b80ff0b1ffabbb9.jpg: 640x640 12 Healthy pods, 7.6ms
# image 82/302 /content/data/validation/images/CACAO-98-_jpg.rf.94fa971e71d8ede74f0436dc79b5ac9f.jpg: 640x640 1 Healthy pod, 7.6ms
# image 83/302 /content/data/validation/images/CACAO-98-_jpg.rf.b655e8d0741fd5de9bba77872ca2b549.jpg: 640x640 1 Healthy pod, 7.6ms
# image 84/302 /content/data/validation/images/CACAO1-1-_jpg.rf.98b2c423fe4155158ee31d68f30bf210.jpg: 640x640 1 Healthy pod, 7.5ms
# image 85/302 /content/data/validation/images/CACAO1-10-_jpg.rf.32d183f1946d3af1e2e72ec65c32b0ab.jpg: 640x640 1 Blackpod rot, 1 Frostypod rot, 4 Healthy pods, 8.2ms
# image 86/302 /content/data/validation/images/CACAO1-103-_jpg.rf.87602ea13c76009213b4f86da7c96f2d.jpg: 640x640 2 Healthy pods, 8.2ms
# image 87/302 /content/data/validation/images/CACAO1-112-_jpg.rf.3b4e14bfa3ad3570a2d57e04579e1fff.jpg: 640x640 1 Healthy pod, 7.4ms
# image 88/302 /content/data/validation/images/CACAO1-118-_jpg.rf.76a23948ee49833eb94093ac862a144e.jpg: 640x640 1 Healthy pod, 7.4ms
# image 89/302 /content/data/validation/images/CACAO1-12-_jpg.rf.f4260294e4118183cca5c6a57673efde.jpg: 640x640 1 Blackpod rot, 6 Healthy pods, 7.7ms
# image 90/302 /content/data/validation/images/CACAO1-134-_jpg.rf.7b04d1fe3bcb78647cc3a9a5bdd4ce68.jpg: 640x640 1 Healthy pod, 7.7ms
# image 91/302 /content/data/validation/images/CACAO1-135-_jpg.rf.a6843ac26aef649067bc288c3a9b1d73.jpg: 640x640 3 Healthy pods, 9.0ms
# image 92/302 /content/data/validation/images/CACAO1-149-_jpg.rf.2ea15f662e8425af65f47d17f25e1396.jpg: 640x640 4 Healthy pods, 7.5ms
# image 93/302 /content/data/validation/images/CACAO1-15-_jpg.rf.b53dafd34c0c0d04fc266343b11442fa.jpg: 640x640 2 Healthy pods, 7.4ms
# image 94/302 /content/data/validation/images/CACAO1-153-_jpg.rf.0ac4c048498004a3a44e1d81192e2162.jpg: 640x640 8 Healthy pods, 7.4ms
# image 95/302 /content/data/validation/images/CACAO1-155-_jpg.rf.bdfede590e3f9f38b9faec6636237bc2.jpg: 640x640 2 Blackpod rots, 3 Healthy pods, 7.5ms
# image 96/302 /content/data/validation/images/CACAO1-172-_jpg.rf.b82cc312051b9e877d099942739ded48.jpg: 640x640 1 Healthy pod, 7.4ms
# image 97/302 /content/data/validation/images/CACAO1-183-_jpg.rf.8e0a1eb397dff8f58f1603e58125cb5d.jpg: 640x640 3 Healthy pods, 9.1ms
# image 98/302 /content/data/validation/images/CACAO1-195-_jpg.rf.75687aaabedb552c864ad45e2006b763.jpg: 640x640 3 Healthy pods, 7.8ms
# image 99/302 /content/data/validation/images/CACAO1-205-_jpg.rf.1674253a4145584845238d88e84d68e6.jpg: 640x640 4 Healthy pods, 7.8ms
# image 100/302 /content/data/validation/images/CACAO1-206-_jpg.rf.82061b41b6680f549397bf93e1be7092.jpg: 640x640 1 Blackpod rot, 2 Healthy pods, 7.6ms
# image 101/302 /content/data/validation/images/CACAO1-207-_jpg.rf.008d7b883ad89e0b069dbb8b5dbd3b44.jpg: 640x640 1 Blackpod rot, 2 Frostypod rots, 4 Healthy pods, 7.5ms
# image 102/302 /content/data/validation/images/CACAO1-212-_jpg.rf.995db2d20c4ea86d5f547e7de8c894d1.jpg: 640x640 1 Blackpod rot, 1 Healthy pod, 7.6ms
# image 103/302 /content/data/validation/images/CACAO1-221-_jpg.rf.5a25ede16339a93269eb360c4036bb57.jpg: 640x640 2 Healthy pods, 7.8ms
# image 104/302 /content/data/validation/images/CACAO1-225-_jpg.rf.fcd5a3bf00106ca88213cc5d34c0b993.jpg: 640x640 1 Healthy pod, 7.4ms
# image 105/302 /content/data/validation/images/CACAO1-237-_jpg.rf.e1efabb9f635f55d95c4e1dda8affdde.jpg: 640x640 1 Blackpod rot, 2 Healthy pods, 7.6ms
# image 106/302 /content/data/validation/images/CACAO1-238-_jpg.rf.e915736a88df61d4c0f863cc2cbd9ff4.jpg: 640x640 1 Healthy pod, 7.8ms
# image 107/302 /content/data/validation/images/CACAO1-24-_jpg.rf.eca8b57552cc8a180ce4b419fd3d78f2.jpg: 640x640 1 Healthy pod, 7.8ms
# image 108/302 /content/data/validation/images/CACAO1-260-_jpg.rf.c17fb654e2f8f6accbdc9badffd5dad2.jpg: 640x640 1 Healthy pod, 7.6ms
# image 109/302 /content/data/validation/images/CACAO1-262-_jpg.rf.dffd58465e015b91442c52fc141c4482.jpg: 640x640 3 Healthy pods, 8.6ms
# image 110/302 /content/data/validation/images/CACAO1-275-_jpg.rf.e9e11aa00522cd0f54cf69a752cdf21c.jpg: 640x640 3 Blackpod rots, 3 Healthy pods, 7.6ms
# image 111/302 /content/data/validation/images/CACAO1-277-_jpg.rf.0147386a3ec93656285bb079908c5bd0.jpg: 640x640 5 Healthy pods, 13.1ms
# image 112/302 /content/data/validation/images/CACAO1-296-_jpg.rf.b1dcc32b03d5648a08d2b30066568425.jpg: 640x640 5 Healthy pods, 7.5ms
# image 113/302 /content/data/validation/images/CACAO1-297-_jpg.rf.2f7b139facead5cf60d9527e7acc1251.jpg: 640x640 2 Healthy pods, 7.9ms
# image 114/302 /content/data/validation/images/CACAO1-301-_jpg.rf.f1914194340dd19a4980af5e51588612.jpg: 640x640 1 Healthy pod, 7.5ms
# image 115/302 /content/data/validation/images/CACAO1-309-_jpg.rf.5c02aaad89b12cb8ace5b6636fba673f.jpg: 640x640 2 Healthy pods, 7.8ms
# image 116/302 /content/data/validation/images/CACAO1-314-_jpg.rf.59ac825b08b51b29ae0895d933019ee6.jpg: 640x640 3 Healthy pods, 7.3ms
# image 117/302 /content/data/validation/images/CACAO1-318-_jpg.rf.42368329bec23405f46e73e07ad3346c.jpg: 640x640 1 Blackpod rot, 6 Healthy pods, 7.4ms
# image 118/302 /content/data/validation/images/CACAO1-46-_jpg.rf.549ca4ad7d68d083838f51ab951e966b.jpg: 640x640 1 Healthy pod, 7.7ms
# image 119/302 /content/data/validation/images/CACAO1-53-_jpg.rf.0dd0a633c8a3ab0d7bb82ae6439adba9.jpg: 640x640 1 Healthy pod, 10.0ms
# image 120/302 /content/data/validation/images/CACAO1-54-_jpg.rf.24d70f59fa8ccce3e24439af8f4f1add.jpg: 640x640 3 Blackpod rots, 1 Healthy pod, 9.9ms
# image 121/302 /content/data/validation/images/CACAO1-59-_jpg.rf.893ba8143838876e0e390bc80332ada0.jpg: 640x640 1 Blackpod rot, 1 Healthy pod, 7.6ms
# image 122/302 /content/data/validation/images/CACAO1-60-_jpg.rf.af3378adad313fe46002694e024a34da.jpg: 640x640 1 Healthy pod, 7.6ms
# image 123/302 /content/data/validation/images/CACAO1-66-_jpg.rf.3697b7da71912bf96017b91db4b61fe8.jpg: 640x640 2 Healthy pods, 7.5ms
# image 124/302 /content/data/validation/images/CACAO1-69-_jpg.rf.ab136a4db620db6fd750a2e87c7be346.jpg: 640x640 1 Frostypod rot, 3 Healthy pods, 7.5ms
# image 125/302 /content/data/validation/images/CACAO1-76-_jpg.rf.c3b0ac6dd95d91e9d3fa7ed6f1c104c0.jpg: 640x640 1 Blackpod rot, 7.5ms
# image 126/302 /content/data/validation/images/CACAO1-87-_jpg.rf.db5a2429fa562877340a14cd526c6363.jpg: 640x640 1 Healthy pod, 7.4ms
# image 127/302 /content/data/validation/images/CACAO1-93-_jpg.rf.d9e0e1630108826d694b8bde3c373750.jpg: 640x640 1 Healthy pod, 7.6ms
# image 128/302 /content/data/validation/images/Fito-196-_jpg.rf.dd5194a1e6e1012120e671e1e37b10e7.jpg: 640x640 1 Blackpod rot, 7.6ms
# image 129/302 /content/data/validation/images/Fito-201-_jpg.rf.b33250ebad90f2e92855c3a44f1cb9b9.jpg: 640x640 3 Blackpod rots, 2 Healthy pods, 7.7ms
# image 130/302 /content/data/validation/images/Fito-235-_jpg.rf.20d3afcd3a130d5ee1a87984bfc68d1f.jpg: 640x640 1 Blackpod rot, 7.9ms
# image 131/302 /content/data/validation/images/Fito-237-_jpg.rf.bd5a74651759e2eacb38c581bc2e68e6.jpg: 640x640 1 Blackpod rot, 2 Healthy pods, 12.8ms
# image 132/302 /content/data/validation/images/Fito-248-_jpg.rf.4f9a072d3fa8fbd427f50fb645e9fa25.jpg: 640x640 1 Blackpod rot, 2 Healthy pods, 7.6ms
# image 133/302 /content/data/validation/images/Fito-251-_jpg.rf.a3f94e49f212c0d431b9bf7f36626b5a.jpg: 640x640 3 Blackpod rots, 1 Healthy pod, 7.4ms
# image 134/302 /content/data/validation/images/Fito-293-_jpg.rf.845537d5a8dc133677b61c1b19903b3e.jpg: 640x640 1 Blackpod rot, 7.4ms
# image 135/302 /content/data/validation/images/Fito-295-_jpg.rf.c526a3a274e2f902100e2b0b5eb32ca8.jpg: 640x640 1 Blackpod rot, 1 Healthy pod, 7.4ms
# image 136/302 /content/data/validation/images/Fito-297-_jpg.rf.401687d612203a0ccf2c7b85200626ea.jpg: 640x640 2 Blackpod rots, 1 Frostypod rot, 1 Healthy pod, 7.7ms
# image 137/302 /content/data/validation/images/Fito-304-_jpg.rf.fb9964d0a773a9c3f2fc47522c84fa96.jpg: 640x640 1 Blackpod rot, 7.7ms
# image 138/302 /content/data/validation/images/Fito-336-_jpg.rf.36692b41d9c79e56dc91d72151ccf39c.jpg: 640x640 1 Blackpod rot, 7.7ms
# image 139/302 /content/data/validation/images/Fito-343-_jpg.rf.1254e5e5a1d1fd1f00bc21092395397b.jpg: 640x640 2 Blackpod rots, 4 Healthy pods, 7.6ms
# image 140/302 /content/data/validation/images/Fito-356-_jpg.rf.c0c5917a6be3254a65245e98b27c8d57.jpg: 640x640 1 Blackpod rot, 3 Healthy pods, 8.2ms
# image 141/302 /content/data/validation/images/Fito-358-_jpg.rf.ee9407accea71014b33510026e582d94.jpg: 640x640 1 Blackpod rot, 1 Frostypod rot, 1 Healthy pod, 7.4ms
# image 142/302 /content/data/validation/images/Fito-359-_jpg.rf.20addbe2545a1fe9389fc59b0c679e32.jpg: 640x640 1 Blackpod rot, 5 Healthy pods, 7.8ms
# image 143/302 /content/data/validation/images/Fito-365-_jpg.rf.fcb69a62e671b2628c5c78f055abcd4c.jpg: 640x640 2 Blackpod rots, 8 Healthy pods, 7.4ms
# image 144/302 /content/data/validation/images/Fito-366-_jpg.rf.57552167bce005875f5c30194d0775d0.jpg: 640x640 1 Blackpod rot, 4 Healthy pods, 7.5ms
# image 145/302 /content/data/validation/images/Fito-372-_jpg.rf.1430624734c274d4b04c1d78fb6271d9.jpg: 640x640 1 Blackpod rot, 1 Healthy pod, 7.4ms
# image 146/302 /content/data/validation/images/Fito-385-_jpg.rf.cc3a82d8cadc9571727e3a7d97f907b2.jpg: 640x640 2 Blackpod rots, 3 Healthy pods, 7.7ms
# image 147/302 /content/data/validation/images/Fito-386-_jpg.rf.b781c150e8aec4132e643ba82e9a9cef.jpg: 640x640 1 Blackpod rot, 3 Healthy pods, 7.6ms
# image 148/302 /content/data/validation/images/Fito-390-_jpg.rf.6f4dd57411cfa1fb17c46cb8ac444a95.jpg: 640x640 2 Blackpod rots, 1 Healthy pod, 7.5ms
# image 149/302 /content/data/validation/images/Fito-402-_jpg.rf.5e1454bceda8c212a25aade59036286a.jpg: 640x640 3 Blackpod rots, 1 Frostypod rot, 3 Healthy pods, 7.5ms
# image 150/302 /content/data/validation/images/Fito-423-_jpg.rf.5d519eaf734180b1a4a2c7c3066adec8.jpg: 640x640 2 Blackpod rots, 22 Healthy pods, 7.4ms
# image 151/302 /content/data/validation/images/Fito-436-_jpg.rf.2411a1d9f4630c695f68038e01e31ed8.jpg: 640x640 2 Blackpod rots, 7.4ms
# image 152/302 /content/data/validation/images/Fito-442-_jpg.rf.f9335eccc86abf04d6d93a00ef1363d1.jpg: 640x640 1 Blackpod rot, 1 Frostypod rot, 2 Healthy pods, 7.4ms
# image 153/302 /content/data/validation/images/Fito101_jpg.rf.e0e84d9e49f2f1edcff0e2db5b1b0c19.jpg: 640x640 1 Blackpod rot, 4 Healthy pods, 7.3ms
# image 154/302 /content/data/validation/images/Fito105_jpg.rf.4dd1f282dc6b3b3c54ae3657185d1213.jpg: 640x640 1 Blackpod rot, 7 Healthy pods, 9.0ms
# image 155/302 /content/data/validation/images/Fito13_jpg.rf.6285351c69266bdd724ccef5d19f9a60.jpg: 640x640 1 Blackpod rot, 1 Healthy pod, 7.6ms
# image 156/302 /content/data/validation/images/Fito16_jpg.rf.e68149bc6e554f566d2410a835f84099.jpg: 640x640 1 Blackpod rot, 2 Healthy pods, 7.7ms
# image 157/302 /content/data/validation/images/Fito20_jpg.rf.11dc2b82636d7d25b917f5451c2a34e8.jpg: 640x640 1 Blackpod rot, 5 Healthy pods, 8.8ms
# image 158/302 /content/data/validation/images/Fito21_jpg.rf.fb49a049d32210b0d50902cfb231d434.jpg: 640x640 1 Blackpod rot, 2 Frostypod rots, 1 Healthy pod, 7.4ms
# image 159/302 /content/data/validation/images/Fito22_jpg.rf.1bda94b1ffbcd14830edd36348e6252d.jpg: 640x640 2 Blackpod rots, 5 Healthy pods, 7.5ms
# image 160/302 /content/data/validation/images/Fito23_jpg.rf.4fa2752c759468a301fd7248703df444.jpg: 640x640 1 Blackpod rot, 6 Healthy pods, 7.5ms
# image 161/302 /content/data/validation/images/Fito27_jpg.rf.d85d81ae3a5055bd4faab1fbf6188cd2.jpg: 640x640 1 Blackpod rot, 3 Healthy pods, 8.0ms
# image 162/302 /content/data/validation/images/Fito28_jpg.rf.8888c2ef6b18c9f47ddd49ef9edc7513.jpg: 640x640 1 Blackpod rot, 5 Healthy pods, 7.7ms
# image 163/302 /content/data/validation/images/Fito29_jpg.rf.0ad96e048189ddedf9c34209c508d4bc.jpg: 640x640 1 Blackpod rot, 7.8ms
# image 164/302 /content/data/validation/images/Fito30_jpg.rf.5386030d720e8367aa33f663ee2fd9be.jpg: 640x640 1 Blackpod rot, 11 Healthy pods, 7.7ms
# image 165/302 /content/data/validation/images/Fito30_jpg.rf.f0348986f20e7c11f033fee3c96dcabf.jpg: 640x640 1 Blackpod rot, 11 Healthy pods, 7.6ms
# image 166/302 /content/data/validation/images/Fito31_jpg.rf.ef4f8a80d82c3fd9df748539366644ef.jpg: 640x640 3 Blackpod rots, 3 Healthy pods, 10.0ms
# image 167/302 /content/data/validation/images/Fito32_jpg.rf.d439f9797f349c956ab952c506181aaf.jpg: 640x640 4 Blackpod rots, 1 Healthy pod, 16.2ms
# image 168/302 /content/data/validation/images/Fito36_jpg.rf.843f1f4c86970aa4ad82de1af603e8d5.jpg: 640x640 2 Blackpod rots, 4 Healthy pods, 7.6ms
# image 169/302 /content/data/validation/images/Fito38_jpg.rf.b029c93d9375c5abe9bc93dbe3f6d912.jpg: 640x640 1 Blackpod rot, 1 Frostypod rot, 5 Healthy pods, 7.8ms
# image 170/302 /content/data/validation/images/Fito40_jpg.rf.5510f26332ccff288422429b5084e1e7.jpg: 640x640 1 Blackpod rot, 1 Healthy pod, 7.4ms
# image 171/302 /content/data/validation/images/Fito46_jpg.rf.3973f13369c8c43247a525f8e46e394d.jpg: 640x640 2 Blackpod rots, 3 Healthy pods, 7.5ms
# image 172/302 /content/data/validation/images/Fito47_jpg.rf.a2489eacf0dae01c7de7dcb34ee3524d.jpg: 640x640 1 Blackpod rot, 3 Healthy pods, 7.4ms
# image 173/302 /content/data/validation/images/Fito49_jpg.rf.9abb2d165303c32f73e6252435e18f54.jpg: 640x640 1 Blackpod rot, 6 Healthy pods, 10.3ms
# image 174/302 /content/data/validation/images/Fito49_jpg.rf.e07eeb7a7601b9aead37a34ad0455a96.jpg: 640x640 1 Blackpod rot, 6 Healthy pods, 7.3ms
# image 175/302 /content/data/validation/images/Fito5_jpg.rf.76c8e3c53285f776d4ad03c839d14921.jpg: 640x640 1 Blackpod rot, 1 Frostypod rot, 1 Healthy pod, 7.3ms
# image 176/302 /content/data/validation/images/Fito60_jpg.rf.658dc9ec9306481ee9c1aead05dc55d6.jpg: 640x640 1 Blackpod rot, 12 Healthy pods, 7.3ms
# image 177/302 /content/data/validation/images/Fito60_jpg.rf.c3db98b41ce2590a075e813bae9f1018.jpg: 640x640 1 Blackpod rot, 12 Healthy pods, 7.3ms
# image 178/302 /content/data/validation/images/Fito60_jpg.rf.d4e99933968ce50e8c56dea517d4fe3f.jpg: 640x640 1 Blackpod rot, 12 Healthy pods, 7.3ms
# image 179/302 /content/data/validation/images/Fito6_jpg.rf.9939292b4e068b8953035df27a5aeac4.jpg: 640x640 2 Blackpod rots, 5 Healthy pods, 7.5ms
# image 180/302 /content/data/validation/images/Fito75_jpg.rf.f545ec79f63c253e8e4ea9335b44e153.jpg: 640x640 1 Blackpod rot, 7.3ms
# image 181/302 /content/data/validation/images/Fito77_jpg.rf.8182355e57b742c72a9f901f99424d49.jpg: 640x640 1 Blackpod rot, 1 Frostypod rot, 10 Healthy pods, 7.3ms
# image 182/302 /content/data/validation/images/Fito79_jpg.rf.ffbf05b044ed73695e6b03e92e4407b1.jpg: 640x640 1 Blackpod rot, 2 Healthy pods, 7.4ms
# image 183/302 /content/data/validation/images/Fito82_jpg.rf.abc7693f3a128c28a2d023a4b38314d7.jpg: 640x640 1 Blackpod rot, 1 Healthy pod, 7.6ms
# image 184/302 /content/data/validation/images/Fito91_jpg.rf.7e2fec7cdde3960aa1ac5530040060c9.jpg: 640x640 2 Blackpod rots, 6 Healthy pods, 7.3ms
# image 185/302 /content/data/validation/images/Fito92_jpg.rf.aeafa34f7d232f524c478a070790f075.jpg: 640x640 1 Blackpod rot, 6 Healthy pods, 7.3ms
# image 186/302 /content/data/validation/images/Fito96_jpg.rf.cfe7315777cdb56c99adb7a6337da744.jpg: 640x640 2 Blackpod rots, 7.3ms
# image 187/302 /content/data/validation/images/Fito99_jpg.rf.465ec948e6b4ddd6aea8c506e50ac044.jpg: 640x640 2 Blackpod rots, 3 Healthy pods, 7.4ms
# image 188/302 /content/data/validation/images/Fito99_jpg.rf.7e622933bd8913632e4fd6da707fdd82.jpg: 640x640 1 Blackpod rot, 3 Healthy pods, 7.7ms
# image 189/302 /content/data/validation/images/Fito_100_jpg.rf.517fdb03e7f9bf92ff3c8007bee6be62.jpg: 640x640 2 Blackpod rots, 1 Healthy pod, 7.8ms
# image 190/302 /content/data/validation/images/Fito_111_jpg.rf.ae89e5400f5b4d4dd2d2fe1fd5ed8e76.jpg: 640x640 1 Blackpod rot, 7.6ms
# image 191/302 /content/data/validation/images/Fito_121_jpg.rf.32aa099afe26d2cdc528cb2bc9e65c1c.jpg: 640x640 1 Blackpod rot, 7.7ms
# image 192/302 /content/data/validation/images/Fito_155_jpg.rf.54d043a807a12bd3dbdbf3f4bb2ceecf.jpg: 640x640 1 Blackpod rot, 8.2ms
# image 193/302 /content/data/validation/images/Fito_16_jpg.rf.41b6274a7d4346b6fed4078658a969d6.jpg: 640x640 3 Blackpod rots, 3 Healthy pods, 7.6ms
# image 194/302 /content/data/validation/images/Fito_1_jpg.rf.6582c8a57a315d2fe7901c698ee01603.jpg: 640x640 2 Blackpod rots, 1 Healthy pod, 8.9ms
# image 195/302 /content/data/validation/images/Fito_201_jpg.rf.9fd4c57d984b35aedcafc095ac222985.jpg: 640x640 1 Healthy pod, 7.9ms
# image 196/302 /content/data/validation/images/Fito_221_jpg.rf.77f6edb32615c93dad605547c489774f.jpg: 640x640 1 Blackpod rot, 7.8ms
# image 197/302 /content/data/validation/images/Fito_224_jpg.rf.f0ed36ed5346ca24d39123fdb131e58b.jpg: 640x640 1 Blackpod rot, 7.7ms
# image 198/302 /content/data/validation/images/Fito_234_jpg.rf.1b231e7377c07995e2f2517d28c6f284.jpg: 640x640 1 Blackpod rot, 1 Healthy pod, 7.6ms
# image 199/302 /content/data/validation/images/Fito_236_jpg.rf.65a07df49cb15ea32a3b2f41133886d9.jpg: 640x640 2 Blackpod rots, 1 Frostypod rot, 1 Healthy pod, 9.2ms
# image 200/302 /content/data/validation/images/Fito_265_jpg.rf.4819c68e1ac13c57c7c1dd8513472b44.jpg: 640x640 7 Blackpod rots, 2 Healthy pods, 7.6ms
# image 201/302 /content/data/validation/images/Fito_274_jpg.rf.63bf1d316ca741be42abf97072f8bc69.jpg: 640x640 1 Blackpod rot, 7.5ms
# image 202/302 /content/data/validation/images/Fito_55_jpg.rf.5e81e06237cfe7828d22ab07d186cb4c.jpg: 640x640 1 Blackpod rot, 7.5ms
# image 203/302 /content/data/validation/images/Fito_81_jpg.rf.47f4d292a457e34d5f77ed4ed861ab83.jpg: 640x640 1 Blackpod rot, 1 Healthy pod, 7.6ms
# image 204/302 /content/data/validation/images/Fito_87_jpg.rf.e214d376496ac0471a208cd160eda11c.jpg: 640x640 2 Blackpod rots, 7.4ms
# image 205/302 /content/data/validation/images/Fito_8_jpg.rf.9c696bef429ef69eb0fff9cec6f34c8d.jpg: 640x640 1 Blackpod rot, 2 Healthy pods, 7.4ms
# image 206/302 /content/data/validation/images/Fito_90_jpg.rf.eab321620ed57c77ee28daf14e7e8185.jpg: 640x640 1 Blackpod rot, 7.4ms
# image 207/302 /content/data/validation/images/Fito_9_jpg.rf.4b1582fbbfff890a282c08c1921869aa.jpg: 640x640 1 Blackpod rot, 5 Healthy pods, 7.8ms
# image 208/302 /content/data/validation/images/Monilia12_jpg.rf.7064a2e7442a2df02bcfa58bdff76747.jpg: 640x640 1 Frostypod rot, 2 Healthy pods, 7.8ms
# image 209/302 /content/data/validation/images/Monilia15_jpg.rf.00fe8a2b40ce9658da683add3157291f.jpg: 640x640 1 Blackpod rot, 1 Frostypod rot, 7.7ms
# image 210/302 /content/data/validation/images/Monilia15_jpg.rf.64c934af66e1be2c35385f2d75213505.jpg: 640x640 1 Blackpod rot, 1 Frostypod rot, 7.6ms
# image 211/302 /content/data/validation/images/Monilia16_jpg.rf.e094b16f29082840b3055122dc8eb819.jpg: 640x640 1 Blackpod rot, 5 Healthy pods, 7.7ms
# image 212/302 /content/data/validation/images/Monilia1_jpg.rf.e4683de6ebd134bba13eab530544170d.jpg: 640x640 2 Frostypod rots, 4 Healthy pods, 8.5ms
# image 213/302 /content/data/validation/images/Monilia20_jpg.rf.ddf5408e2e76d9dc4743e40050869c52.jpg: 640x640 1 Frostypod rot, 4 Healthy pods, 7.7ms
# image 214/302 /content/data/validation/images/Monilia38_jpg.rf.4219933a71360e68ec270c86389adb22.jpg: 640x640 1 Frostypod rot, 3 Healthy pods, 7.4ms
# image 215/302 /content/data/validation/images/Monilia41_jpg.rf.7cbc1d973523a3827f33ec85794fce57.jpg: 640x640 1 Frostypod rot, 8 Healthy pods, 7.4ms
# image 216/302 /content/data/validation/images/Monilia49_jpg.rf.26141b7865d25a0f5f7b89ef237692be.jpg: 640x640 1 Frostypod rot, 3 Healthy pods, 7.4ms
# image 217/302 /content/data/validation/images/Monilia60_jpg.rf.49175798aea668f00bbb882c628920cf.jpg: 640x640 1 Frostypod rot, 3 Healthy pods, 7.4ms
# image 218/302 /content/data/validation/images/Monilia64_jpg.rf.3948f8f9ef9826e97c094e18de4498b6.jpg: 640x640 1 Frostypod rot, 2 Healthy pods, 7.5ms
# image 219/302 /content/data/validation/images/Monilia66_jpg.rf.169220805b1e5f81874f2c8d51ae352f.jpg: 640x640 1 Frostypod rot, 7.8ms
# image 220/302 /content/data/validation/images/Monilia6_jpg.rf.58c59bb70d2188d8a193c9ceefccd8e3.jpg: 640x640 1 Blackpod rot, 1 Frostypod rot, 5 Healthy pods, 7.7ms
# image 221/302 /content/data/validation/images/Monilia74_jpg.rf.562e95a9ab6b852ff76d9d4014654a9a.jpg: 640x640 1 Blackpod rot, 1 Frostypod rot, 1 Healthy pod, 7.5ms
# image 222/302 /content/data/validation/images/Monilia75_jpg.rf.1e075b3a418a81875ffc70e092e453e7.jpg: 640x640 1 Frostypod rot, 7 Healthy pods, 12.3ms
# image 223/302 /content/data/validation/images/Monilia80_jpg.rf.0f93f65863361c82e44039667fa866bf.jpg: 640x640 2 Blackpod rots, 1 Frostypod rot, 6 Healthy pods, 7.7ms
# image 224/302 /content/data/validation/images/Monilia80_jpg.rf.32d419680147504236ff2f5463abad60.jpg: 640x640 2 Blackpod rots, 1 Frostypod rot, 6 Healthy pods, 7.5ms
# image 225/302 /content/data/validation/images/Monilia84_jpg.rf.8378d5126eec0a62b70e18c1cef73634.jpg: 640x640 1 Frostypod rot, 17 Healthy pods, 7.6ms
# image 226/302 /content/data/validation/images/Monilia84_jpg.rf.c464aff063d0a96fd57454b0f1be4a01.jpg: 640x640 1 Frostypod rot, 18 Healthy pods, 13.0ms
# image 227/302 /content/data/validation/images/Monilia8_jpg.rf.01ddd0599c9949821984e6007109addf.jpg: 640x640 1 Blackpod rot, 1 Frostypod rot, 4 Healthy pods, 7.9ms
# image 228/302 /content/data/validation/images/Monilia8_jpg.rf.d61c8f64eb0100d6dc75f86751676c40.jpg: 640x640 1 Blackpod rot, 1 Frostypod rot, 4 Healthy pods, 7.4ms
# image 229/302 /content/data/validation/images/Monilia94_jpg.rf.97e12eac9159ca0473b430f35a5b4c98.jpg: 640x640 1 Blackpod rot, 1 Frostypod rot, 1 Healthy pod, 7.9ms
# image 230/302 /content/data/validation/images/Monilia96_jpg.rf.e90cbc811ba5fbd420bd68d21daf867c.jpg: 640x640 1 Frostypod rot, 5 Healthy pods, 8.0ms
# image 231/302 /content/data/validation/images/Monilia9_jpg.rf.abaad52ca3f01234d4a1ea06d2059925.jpg: 640x640 1 Frostypod rot, 7.8ms
# image 232/302 /content/data/validation/images/Monilia_48_jpg.rf.205226b56f6a2afe36efd0abdf27efff.jpg: 640x640 1 Frostypod rot, 7.6ms
# image 233/302 /content/data/validation/images/Monilia_5_jpg.rf.092e205e804c8035d6f7cb1bc3ec8051.jpg: 640x640 1 Frostypod rot, 4 Healthy pods, 7.5ms
# image 234/302 /content/data/validation/images/Monilia_60_jpg.rf.0d2f387625a06ea3704681b3e31e52e5.jpg: 640x640 1 Frostypod rot, 7.5ms
# image 235/302 /content/data/validation/images/Monilia_75_jpg.rf.eeef5417d16c1c29449d5ce3aa8ffa24.jpg: 640x640 1 Frostypod rot, 7.4ms
# image 236/302 /content/data/validation/images/Monilia_9_jpg.rf.cb7d5facf6485d8a6e6d71eee00add35.jpg: 640x640 1 Blackpod rot, 1 Frostypod rot, 3 Healthy pods, 7.8ms
# image 237/302 /content/data/validation/images/Sana100_jpg.rf.342c13a8966f69818d1a4dba1d997819.jpg: 640x640 6 Healthy pods, 7.8ms
# image 238/302 /content/data/validation/images/Sana100_jpg.rf.df92e577b51b60c24a343af7e5fa60b2.jpg: 640x640 7 Healthy pods, 7.7ms
# image 239/302 /content/data/validation/images/Sana14_jpg.rf.a3818f0f1eb7c428230896a57edf7105.jpg: 640x640 12 Healthy pods, 7.5ms
# image 240/302 /content/data/validation/images/Sana28_jpg.rf.5e29b3eb104c0efa77d4c19c0d847ea5.jpg: 640x640 21 Healthy pods, 7.4ms
# image 241/302 /content/data/validation/images/Sana34_jpg.rf.8b01291b20e6c166877822ce20c503c3.jpg: 640x640 2 Blackpod rots, 1 Frostypod rot, 7 Healthy pods, 7.4ms
# image 242/302 /content/data/validation/images/Sana3_jpg.rf.4fbe0b9c74f865210e1bebbbb1c9ddfa.jpg: 640x640 12 Healthy pods, 7.4ms
# image 243/302 /content/data/validation/images/Sana3_jpg.rf.9fcad7e245eea8bb90b210f79056f0ba.jpg: 640x640 11 Healthy pods, 7.4ms
# image 244/302 /content/data/validation/images/Sana40_jpg.rf.c7aed1cb8eab9abdf174fb04b281fbb9.jpg: 640x640 9 Healthy pods, 7.3ms
# image 245/302 /content/data/validation/images/Sana48_jpg.rf.7c3e1e1f76f195d4013d6ba9fd8a6b2c.jpg: 640x640 19 Healthy pods, 8.4ms
# image 246/302 /content/data/validation/images/Sana53_jpg.rf.96b13273b875d4e64f009144eec2761c.jpg: 640x640 7 Healthy pods, 7.4ms
# image 247/302 /content/data/validation/images/Sana53_jpg.rf.d0ea60e2b5860954aabc7aaf42e7b809.jpg: 640x640 7 Healthy pods, 7.4ms
# image 248/302 /content/data/validation/images/Sana55_jpg.rf.d6db5a8a99b48d6685368e8cbe415279.jpg: 640x640 15 Healthy pods, 7.4ms
# image 249/302 /content/data/validation/images/Sana56_jpg.rf.1a001312819c1b636fee44af0c9bb7e9.jpg: 640x640 1 Blackpod rot, 10 Healthy pods, 7.5ms
# image 250/302 /content/data/validation/images/Sana59_jpg.rf.2ef0649e567df7bf85b9c6ec9873c460.jpg: 640x640 9 Healthy pods, 9.4ms
# image 251/302 /content/data/validation/images/Sana5_jpg.rf.f4d41a767d8a2f380f1ec732fe60fa6a.jpg: 640x640 6 Healthy pods, 7.4ms
# image 252/302 /content/data/validation/images/Sana6_jpg.rf.a9f91d8aa41b72e4e7240de273b45cfa.jpg: 640x640 3 Healthy pods, 7.5ms
# image 253/302 /content/data/validation/images/Sana71_jpg.rf.520b86f1ef56c3e83a3b533fb1ed5fc7.jpg: 640x640 1 Blackpod rot, 4 Healthy pods, 7.6ms
# image 254/302 /content/data/validation/images/Sana72_jpg.rf.4ff4a99e8aebd9a9133ef2a8d2efa13c.jpg: 640x640 18 Healthy pods, 7.5ms
# image 255/302 /content/data/validation/images/Sana73_jpg.rf.b520cf6899a176e5b66a10fcfdad33c9.jpg: 640x640 7 Healthy pods, 7.5ms
# image 256/302 /content/data/validation/images/Sana74_jpg.rf.58390f959c7bc57472daabb7df787c40.jpg: 640x640 11 Healthy pods, 7.5ms
# image 257/302 /content/data/validation/images/Sana76_jpg.rf.188fbdad769ca741db4a9593ad8ad1c7.jpg: 640x640 3 Healthy pods, 7.7ms
# image 258/302 /content/data/validation/images/Sana77_jpg.rf.fd20ca2e05eda4c2b201d18df481582f.jpg: 640x640 10 Healthy pods, 7.7ms
# image 259/302 /content/data/validation/images/Sana7_jpg.rf.cfb6fbbe5b0b771a53751c54ed8946b5.jpg: 640x640 1 Blackpod rot, 10 Healthy pods, 7.6ms
# image 260/302 /content/data/validation/images/Sana7_jpg.rf.df929fc2e5b88aef7624d699f738435b.jpg: 640x640 1 Blackpod rot, 11 Healthy pods, 7.9ms
# image 261/302 /content/data/validation/images/Sana80_jpg.rf.fbdc5ea6264aaad36c7d8b2765d893fe.jpg: 640x640 6 Healthy pods, 7.8ms
# image 262/302 /content/data/validation/images/Sana84_jpg.rf.f71cad586e5607746b60d00e889e87b6.jpg: 640x640 6 Healthy pods, 7.5ms
# image 263/302 /content/data/validation/images/Sana85_jpg.rf.36f23c7421d48751d2a8426a3c8cd898.jpg: 640x640 1 Blackpod rot, 2 Frostypod rots, 2 Healthy pods, 7.5ms
# image 264/302 /content/data/validation/images/Sana8_jpg.rf.e030fe8fc170c2847d7b352a79d5dae7.jpg: 640x640 1 Blackpod rot, 3 Healthy pods, 7.6ms
# image 265/302 /content/data/validation/images/Sana92_jpg.rf.1f1dd7f692306b6013da032dddf5577b.jpg: 640x640 1 Blackpod rot, 5 Healthy pods, 7.6ms
# image 266/302 /content/data/validation/images/Sana93_jpg.rf.6246481dbb022148e9c447e183246ee8.jpg: 640x640 1 Blackpod rot, 1 Frostypod rot, 5 Healthy pods, 10.9ms
# image 267/302 /content/data/validation/images/Sana94_jpg.rf.0edbc99c01f2810d2333988b6affda65.jpg: 640x640 4 Blackpod rots, 1 Frostypod rot, 2 Healthy pods, 7.9ms
# image 268/302 /content/data/validation/images/Sana94_jpg.rf.f95c8c02b95929c82aca901039ae19ff.jpg: 640x640 4 Blackpod rots, 1 Frostypod rot, 2 Healthy pods, 7.5ms
# image 269/302 /content/data/validation/images/Sana99_jpg.rf.71b10aba0e509fb543342c5146d114f3.jpg: 640x640 1 Blackpod rot, 16 Healthy pods, 7.5ms
# image 270/302 /content/data/validation/images/Sana9_jpg.rf.97510b239ca182d4bc0b35bc224d341e.jpg: 640x640 6 Healthy pods, 8.0ms
# image 271/302 /content/data/validation/images/Sana_110_jpg.rf.f427ddbb0ed4342b94cc2828e01e232f.jpg: 640x640 3 Healthy pods, 9.6ms
# image 272/302 /content/data/validation/images/Sana_111_jpg.rf.a9e7d97407768eafdc40e78234ab29b6.jpg: 640x640 2 Healthy pods, 13.8ms
# image 273/302 /content/data/validation/images/Sana_115_jpg.rf.a6c083219a5fa20b2510fa292d3c6369.jpg: 640x640 2 Healthy pods, 7.5ms
# image 274/302 /content/data/validation/images/Sana_130_jpg.rf.14f74df4e5507e5e8fc0df7c36d2cefd.jpg: 640x640 1 Healthy pod, 7.5ms
# image 275/302 /content/data/validation/images/Sana_133_jpg.rf.3fb92551a027082faf742576fcf068ad.jpg: 640x640 1 Healthy pod, 9.5ms
# image 276/302 /content/data/validation/images/Sana_148_jpg.rf.b05d02b3c08f2bd515a1ecdf36f9b879.jpg: 640x640 1 Healthy pod, 7.5ms
# image 277/302 /content/data/validation/images/Sana_153_jpg.rf.c0a34b65514120285ff3ae34c69ea9ff.jpg: 640x640 1 Healthy pod, 7.6ms
# image 278/302 /content/data/validation/images/Sana_158_jpg.rf.b53fd42f247f6d3423284e4817251cfa.jpg: 640x640 2 Healthy pods, 7.7ms
# image 279/302 /content/data/validation/images/Sana_166_jpg.rf.85e91991b248463c143d72f7f02d4271.jpg: 640x640 1 Blackpod rot, 1 Healthy pod, 7.7ms
# image 280/302 /content/data/validation/images/Sana_168_jpg.rf.97dc4099c4fe1a863cfd1d698299ed87.jpg: 640x640 1 Healthy pod, 7.5ms
# image 281/302 /content/data/validation/images/Sana_173_jpg.rf.8987e62cee59dcfb0a4f35bd4705a8f4.jpg: 640x640 1 Healthy pod, 7.5ms
# image 282/302 /content/data/validation/images/Sana_180_jpg.rf.01a93827a9bd4bc768366629db564659.jpg: 640x640 2 Healthy pods, 13.8ms
# image 283/302 /content/data/validation/images/Sana_182_jpg.rf.bbb1232b986e5d05b1bc1c2ef2eda4e1.jpg: 640x640 1 Blackpod rot, 2 Healthy pods, 7.7ms
# image 284/302 /content/data/validation/images/Sana_190_jpg.rf.cc086b2bb364febcc7611fb8d4250eeb.jpg: 640x640 1 Healthy pod, 7.8ms
# image 285/302 /content/data/validation/images/Sana_193_jpg.rf.63c51343cb927ad5b281fb6048782146.jpg: 640x640 1 Healthy pod, 7.8ms
# image 286/302 /content/data/validation/images/Sana_206_jpg.rf.26253f686fe6eeda0e3856549e510e68.jpg: 640x640 2 Healthy pods, 7.7ms
# image 287/302 /content/data/validation/images/Sana_228_jpg.rf.d4f180ff5b31964c884bb36969b13fc7.jpg: 640x640 2 Healthy pods, 7.7ms
# image 288/302 /content/data/validation/images/Sana_239_jpg.rf.2e326ee04627f25b44c4f500ff1eadf0.jpg: 640x640 1 Healthy pod, 7.5ms
# image 289/302 /content/data/validation/images/Sana_269_jpg.rf.fb42a5f31379fe2bfa1b0ea2bf90e020.jpg: 640x640 5 Healthy pods, 7.6ms
# image 290/302 /content/data/validation/images/Sana_272_jpg.rf.42c3db1f0d1fd378977d53b321aea722.jpg: 640x640 1 Healthy pod, 7.7ms
# image 291/302 /content/data/validation/images/Sana_274_jpg.rf.a863e7df17f72b8f0abc1e4c3399a8d0.jpg: 640x640 1 Frostypod rot, 1 Healthy pod, 7.9ms
# image 292/302 /content/data/validation/images/Sana_28_jpg.rf.2b1aabcdb565d282f97ee0ee60031270.jpg: 640x640 1 Healthy pod, 7.8ms
# image 293/302 /content/data/validation/images/Sana_296_jpg.rf.7c055ec92274fcbad5b5ff5ab2e75d61.jpg: 640x640 4 Healthy pods, 10.2ms
# image 294/302 /content/data/validation/images/Sana_2_jpg.rf.8320853ae77db065382c9af1dbef9761.jpg: 640x640 1 Healthy pod, 7.7ms
# image 295/302 /content/data/validation/images/Sana_306_jpg.rf.231ec07a1e2a70b86e587b6b8a1406ec.jpg: 640x640 3 Healthy pods, 7.4ms
# image 296/302 /content/data/validation/images/Sana_317_jpg.rf.c738853f66632e83c7348e5e6df671f4.jpg: 640x640 1 Blackpod rot, 1 Healthy pod, 8.4ms
# image 297/302 /content/data/validation/images/Sana_318_jpg.rf.7876642078ff1381e6f9d65c6014c482.jpg: 640x640 1 Healthy pod, 9.1ms
# image 298/302 /content/data/validation/images/Sana_54_jpg.rf.c9a077728061bd4df910f5aad1e627f5.jpg: 640x640 3 Healthy pods, 7.7ms
# image 299/302 /content/data/validation/images/Sana_58_jpg.rf.83a7aba46e2cc79f02a9cf27191a5e06.jpg: 640x640 1 Blackpod rot, 1 Healthy pod, 7.6ms
# image 300/302 /content/data/validation/images/Sana_67_jpg.rf.d0974f83a2293864029c791808837b24.jpg: 640x640 6 Healthy pods, 7.5ms
# image 301/302 /content/data/validation/images/Sana_82_jpg.rf.96626d08daae934e099df1ba814e35f0.jpg: 640x640 2 Healthy pods, 7.4ms
# image 302/302 /content/data/validation/images/Sana_83_jpg.rf.9b5e750eae18ddf06e3c25d7f8386ea5.jpg: 640x640 1 Healthy pod, 7.4ms
# Speed: 1.4ms preprocess, 8.7ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to /content/runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
import glob
from IPython.display import Image, display
for image_path in glob.glob(f'/content/runs/detect/predict/*.jpg')[:10]:
  display(Image(filename=image_path, height=400))
  print('\n')

# %% [markdown]
# The model should draw a box around each object of interest in each image. If it isn't doing a good job of detecting objects, here are a few tips:
#
# 1. Double-check your dataset to make sure there are no labeling errors or conflicting examples.
# 2. Increase the number of epochs used for training.
# 3. Use a larger model size (e.g. `yolo11l.pt`).
# 4. Add more images to the training dataset. See my [dataset video](https://www.youtube.com/watch?v=v0ssiOY6cfg) for tips on how to capture good training images and improve accuracy.
#
# You can also run the model on video files or other images images by uploading them to this notebook and using the above `!yolo detect predict` command, where `source` points to the location of the video file, image, or folder of images. The results will be saved in `runs/detect/predict`.
#
# Drawing boxes on images is great, but it isn't very useful in itself. It's also not very helpful to just run this models inside a Colab notebook: it's easier if we can just run it on a local computer. Continue to the next section to see how to download your newly trained model and run it on a local device.

# %% [markdown]
# #7.&nbsp;Deploy Model

# %% [markdown]
# Now that your custom model has been trained, it's ready to be downloaded and deployed in an application! YOLO models can run on a wide variety of hardware, including PCs, embedded systems, and phones. Ultralytics makes it easy to convert the YOLO models to various formats (`tflite`, `onnx`, etc.) and deploy them in a variety of environments.
#
# This section shows how to download the model and provides links to instructions for deploying it on your PC and edge devices like the Raspberry Pi.

# %% [markdown]
# ## 7.1 Download YOLO Model
#
# First, zip and download the trained model by running the code blocks below.
#
# The code creates a folder named `my_model`, moves the model weights into it, and renames them from `best.pt` to `my_model.pt`. It also adds the training results in case you want to reference them later. It then zips the folder as `my_model.zip`.

# %%
# Create "my_model" folder to store model weights and train results
# !mkdir /content/my_model
# !cp /content/runs/detect/train/weights/best.pt /content/my_model/my_model.pt
# !cp -r /content/runs/detect/train /content/my_model

# Zip into "my_model.zip"
# %cd my_model
# !zip /content/my_model.zip my_model.pt
# !zip -r /content/my_model.zip train
# %cd /content

# %%
# This takes forever for some reason, you can also just download the model from the sidebar
from google.colab import files

files.download('/content/my_model.zip')

# %% [markdown]
# ## 7.2 Deploy YOLO Model on Local Devices
#
# Next, we'll take our downloaded model and run it on a local device. This section provides instructions showing how to deploy YOLO models on various devices.
#
# I wrote a basic Python script, `yolo_detect.py`, that shows how to load a model, run inference on an image source, parse the inference results, and display boxes around each detected class in the image. The [script](https://github.com/EdjeElectronics/Train-and-Deploy-YOLO-Models/blob/main/yolo_detect.py) gives an example of how to work with Ultralytics YOLO models in Python, and it can be used as a starting point for more advanced applications.

# %% [markdown]
# ### 7.2.1 Deploy on PC (Windows, Linux, or macOS)
#
# The easiest way to run Ultralytics models on a PC is using Anaconda. Anaconda sets up a virtual Python environment and allows you to easily install Ultralytics and PyTorch. It automatically installs CUDA and cuDNN, which allows you to speed up model inference with your NVIDIA GPU.
#
# > **NOTE:** My YouTube video (link to be added) shows how to deploy your model on a PC. It walks through the following steps, so watch the video if you prefer having visual instructions.
#
# **1. Download and Install Anaconda**
#
# Go to the Anaconda download page at https://anaconda.com/download, click the “skip registration” button, and then download the package for your OS. When it's finished downloading, run the installer and click through the installation steps. You can use the default options for installation.
#
# **2. Set up virtual environment**
#
# Once it's installed, run Anaconda Prompt from the Start Bar. (If you're on macOS or Linux, just open a command terminal).
#
# Issue the following commands to create a new Python environment and activate it:
#
# ```
# conda create --name yolo-env1 python=3.12 -y
# conda activate yolo-env1
# ```
#
# Install Ultralytics (which also installs import libraries like OpenCV-Python, Numpy, and PyTorch) by issuing the following command:
#
# ```
# pip install ultralytics
# ```
#
# If you have an NVIDIA GPU, you can install the GPU-enabled version of PyTorch by issuing the following command:
#
# ```
# pip install --upgrade torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu124
# ```
#
# **3. Extract downloaded model**
# Take the `my_model.zip` file you downloaded in Step 7.1 and unzip it to a folder on your PC. In the Anaconda Prompt terminal, move into the unzipped folder using:
#
# ```
# cd path/to/folder
# ```
#
# **4. Download and run yolo_detect.py**
#
# Download the `yolo_detect.py` script into the `my_model` folder using:
#
# ```
# curl -o yolo_detect.py https://raw.githubusercontent.com/EdjeElectronics/Train-and-Deploy-YOLO-Models/refs/heads/main/yolo_detect.py
# ```
#
# Alright! We're ready to run the script. To run inference with a yolov8s model on a USB camera at 1280x720 resolution, issue:
#
# ```
# python yolo_detect.py --model my_model.pt --source usb0 --resolution 1280x720
# ```
#
# A window will appear showing a live feed from your webcam with boxes drawn around detected objects in each frame.
#
# You can also run the model on an video file, image, or folder of images. To see a full list of arguments for `yolo_detect.py`, issue `python yolo_detect.py --help` or see the [README file](https://github.com/EdjeElectronics/Train-and-Deploy-YOLO-Models/blob/main/README.md).

# %% [markdown]
# ### 7.2.2 Deploy on Raspberry Pi
#
# Keep an eye out for an article showing how to convert YOLO models to NCNN format and run them on the Raspberry Pi!

# %% [markdown]
# # 8.&nbsp;Conclusion

# %% [markdown]
# Congratulations! You've successfully trained and deployed a YOLO object detection model. 😀
#
# Next, you can extend your application beyond just drawing boxes and counting objects. Add functionality like logging the number of objects detected over time or taking a picture when certain objects are detected. Check out some example applications at our GitHub repository: https://github.com/EdjeElectronics/Train-and-Deploy-YOLO-Models
#
# Thanks for working through this notebook, and good luck with your projects!

# %% [markdown]
# # Appendix: Common Errors

# %% [markdown]
# If you run into any errors working through this notebook, please do the following:
#
#
# - Double-check that the dataset files are set up in the correct folder structure
# - Make sure there are no typos or errors in your labelmap file
# - Google search the error to look for solutions
#
# If none of those help, please submit an [Issue](https://github.com/EdjeElectronics/Train-and-Deploy-YOLO-Models/issues) on the GitHub page. In this section, I will add resolutions to common errors as they come up.

# %%
# ✅ Step 2: Import required libraries
from ultralytics import YOLO

# ✅ Step 3: Load your trained YOLO11s model
model = YOLO("/content/runs/detect/train/weights/best.pt")  # Make sure this file is in your Colab workspace

# ✅ Step 4: Export to TensorFlow Lite format
model.export(format="tflite")

# ✅ Optional: List exported files
import os
for file in os.listdir("runs/export"):
    print("Exported:", file)
# Out:
# Requirement already satisfied: ultralytics in /usr/local/lib/python3.12/dist-packages (8.3.203)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.0.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (4.12.0.88)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (11.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.32.4)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.16.2)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.8.0+cu126)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (0.23.0+cu126)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: polars in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.25.2)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.0.17)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.60.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.2.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (2025.8.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.4.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)
# Ultralytics 8.3.203 🚀 Python-3.12.11 torch-2.8.0+cu126 CPU (Intel Xeon CPU @ 2.00GHz)
# 💡 ProTip: Export to OpenVINO format for best performance on Intel hardware. Learn more at https://docs.ultralytics.com/integrations/openvino/
# YOLO11s summary (fused): 100 layers, 9,443,760 parameters, 0 gradients, 21.5 GFLOPs
#
# PyTorch: starting from 'yolo11s.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 84, 8400) (18.4 MB)
# requirements: Ultralytics requirements ['sng4onnx>=1.0.1', 'onnx_graphsurgeon>=0.3.26', 'ai-edge-litert>=1.2.0', 'onnx>=1.12.0', 'onnx2tf>=1.26.3', 'onnxslim>=0.1.67', 'onnxruntime'] not found, attempting AutoUpdate...
#
# requirements: AutoUpdate success ✅ 11.2s
# WARNING ⚠️ requirements: Restart runtime or rerun command for updates to take effect
#
#
# TensorFlow SavedModel: starting export with tensorflow 2.19.0...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/calibration_image_sample_data_20x128x128x3_float32.npy.zip to 'calibration_image_sample_data_20x128x128x3_float32.npy.zip': 100% ━━━━━━━━━━━━ 1.1MB 175.8MB/s 0.0s
# Unzipping calibration_image_sample_data_20x128x128x3_float32.npy.zip to /content/calibration_image_sample_data_20x128x128x3_float32.npy...: 100% ━━━━━━━━━━━━ 1/1 46.0files/s 0.0s
#
# ONNX: starting export with onnx 1.19.0 opset 22...
# ONNX: slimming with onnxslim 0.1.69...
# ONNX: export success ✅ 2.5s, saved as 'yolo11s.onnx' (36.4 MB)
# TensorFlow SavedModel: starting TFLite export with onnx2tf 1.28.2...
# Saved artifact at 'yolo11s_saved_model'. The following endpoints are available:
#
# * Endpoint 'serving_default'
#   inputs_0 (POSITIONAL_ONLY): TensorSpec(shape=(1, 640, 640, 3), dtype=tf.float32, name='images')
# Output Type:
#   TensorSpec(shape=(1, 84, 8400), dtype=tf.float32, name=None)
# Captures:
#   134054367351376: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   134054367351952: TensorSpec(shape=(3, 3, 3, 32), dtype=tf.float32, name=None)
#   134054367352144: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   134054367356368: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   134054367356752: TensorSpec(shape=(3, 3, 32, 64), dtype=tf.float32, name=None)
#   134054367354832: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   134054367357136: TensorSpec(shape=(1, 1, 64, 64), dtype=tf.float32, name=None)
#   134054367352336: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   134054367357904: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   134054367357520: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   134054367359824: TensorSpec(shape=(3, 3, 32, 16), dtype=tf.float32, name=None)
#   134054367360400: TensorSpec(shape=(16,), dtype=tf.float32, name=None)
#   134054367357328: TensorSpec(shape=(3, 3, 16, 32), dtype=tf.float32, name=None)
#   134054367353680: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   134054367358480: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   134054367358096: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   134054367360592: TensorSpec(shape=(1, 1, 96, 128), dtype=tf.float32, name=None)
#   134054367361168: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   134054367359440: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   134054367361552: TensorSpec(shape=(3, 3, 128, 128), dtype=tf.float32, name=None)
#   134054367359248: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   134054367361744: TensorSpec(shape=(1, 1, 128, 128), dtype=tf.float32, name=None)
#   134054367361360: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   134054367362704: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   134054367361936: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   134054367360016: TensorSpec(shape=(3, 3, 64, 32), dtype=tf.float32, name=None)
#   134054367360976: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   134054367360784: TensorSpec(shape=(3, 3, 32, 64), dtype=tf.float32, name=None)
#   134054367362896: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   134054367362128: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   134054367362512: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   134054368439248: TensorSpec(shape=(1, 1, 192, 256), dtype=tf.float32, name=None)
#   134054368443664: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   134054368442896: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   134054368441936: TensorSpec(shape=(3, 3, 256, 256), dtype=tf.float32, name=None)
#   134054368441744: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   134054368443280: TensorSpec(shape=(1, 1, 256, 256), dtype=tf.float32, name=None)
#   134054368442704: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   134054367351568: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   134054367346960: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   134054367350416: TensorSpec(shape=(1, 1, 128, 64), dtype=tf.float32, name=None)
#   134054376515024: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   134054368441552: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   134054443416656: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   134054407854160: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   134054407857040: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   134054407856464: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   134054407855504: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   134054407856272: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   134054368440976: TensorSpec(shape=(1, 1, 128, 64), dtype=tf.float32, name=None)
#   134054407852816: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   134054368444048: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   134054407855120: TensorSpec(shape=(1, 1, 128, 128), dtype=tf.float32, name=None)
#   134054407854928: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   134054367362320: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   134054367352912: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   134054055052688: TensorSpec(shape=(1, 1, 384, 256), dtype=tf.float32, name=None)
#   134054055052496: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   134054055052880: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   134054055052304: TensorSpec(shape=(3, 3, 256, 512), dtype=tf.float32, name=None)
#   134054055051728: TensorSpec(shape=(512,), dtype=tf.float32, name=None)
#   134054055053264: TensorSpec(shape=(1, 1, 512, 512), dtype=tf.float32, name=None)
#   134054055053456: TensorSpec(shape=(512,), dtype=tf.float32, name=None)
#   134054055054032: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   134054055053840: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   134054055055952: TensorSpec(shape=(1, 1, 256, 128), dtype=tf.float32, name=None)
#   134054055056144: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   134054055055376: TensorSpec(shape=(3, 3, 128, 128), dtype=tf.float32, name=None)
#   134054055056336: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   134054055056528: TensorSpec(shape=(3, 3, 128, 128), dtype=tf.float32, name=None)
#   134054055056720: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   134054055055568: TensorSpec(shape=(3, 3, 128, 128), dtype=tf.float32, name=None)
#   134054055057104: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   134054055054992: TensorSpec(shape=(3, 3, 128, 128), dtype=tf.float32, name=None)
#   134054055053072: TensorSpec(shape=(1, 1, 256, 128), dtype=tf.float32, name=None)
#   134054055057296: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   134054055053648: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   134054055057872: TensorSpec(shape=(1, 1, 256, 256), dtype=tf.float32, name=None)
#   134054055056912: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   134054055054224: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   134054055054416: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   134054055058064: TensorSpec(shape=(1, 1, 768, 512), dtype=tf.float32, name=None)
#   134054055058256: TensorSpec(shape=(512,), dtype=tf.float32, name=None)
#   134054055057488: TensorSpec(shape=(1, 1, 512, 256), dtype=tf.float32, name=None)
#   134054055058448: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   134054055058640: TensorSpec(shape=(1, 1, 1024, 512), dtype=tf.float32, name=None)
#   134054055057680: TensorSpec(shape=(512,), dtype=tf.float32, name=None)
#   134054055059024: TensorSpec(shape=(1, 1, 512, 512), dtype=tf.float32, name=None)
#   134054055059600: TensorSpec(shape=(512,), dtype=tf.float32, name=None)
#   134054055059408: TensorSpec(shape=(1, 1, 256, 512), dtype=tf.float32, name=None)
#   134054055059984: TensorSpec(shape=(512,), dtype=tf.float32, name=None)
#   134054055063632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134054055060176: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   134054055060752: TensorSpec(shape=(1, 1, 256, 256), dtype=tf.float32, name=None)
#   134054055065936: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   134054055066128: TensorSpec(shape=(1, 1, 256, 512), dtype=tf.float32, name=None)
#   134054055065360: TensorSpec(shape=(512,), dtype=tf.float32, name=None)
#   134054055065744: TensorSpec(shape=(1, 1, 512, 256), dtype=tf.float32, name=None)
#   134054055065552: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   134054055065168: TensorSpec(shape=(1, 1, 512, 512), dtype=tf.float32, name=None)
#   134054055064784: TensorSpec(shape=(512,), dtype=tf.float32, name=None)
#   134054055064976: TensorSpec(shape=(1, 1, 768, 256), dtype=tf.float32, name=None)
#   134054055064400: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   134054055064016: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   134054055066704: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   134054055062864: TensorSpec(shape=(3, 3, 128, 64), dtype=tf.float32, name=None)
#   134054055067280: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   134054055066320: TensorSpec(shape=(3, 3, 64, 128), dtype=tf.float32, name=None)
#   134054055067088: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   134054055066896: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   134054055062672: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   134054055066512: TensorSpec(shape=(1, 1, 384, 256), dtype=tf.float32, name=None)
#   134054367331536: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   134054367331728: TensorSpec(shape=(1, 1, 512, 128), dtype=tf.float32, name=None)
#   134054367330576: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   134054367332112: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   134054367331920: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   134054367334032: TensorSpec(shape=(3, 3, 64, 32), dtype=tf.float32, name=None)
#   134054367334224: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   134054367331344: TensorSpec(shape=(3, 3, 32, 64), dtype=tf.float32, name=None)
#   134054367331152: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   134054367332304: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   134054367332496: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   134054367334416: TensorSpec(shape=(1, 1, 192, 128), dtype=tf.float32, name=None)
#   134054367333072: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   134054367334800: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   134054367333456: TensorSpec(shape=(3, 3, 128, 128), dtype=tf.float32, name=None)
#   134054367334608: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   134054367336720: TensorSpec(shape=(1, 1, 384, 256), dtype=tf.float32, name=None)
#   134054367336144: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   134054367336912: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   134054367337680: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   134054367339984: TensorSpec(shape=(3, 3, 128, 64), dtype=tf.float32, name=None)
#   134054367337872: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   134054367339408: TensorSpec(shape=(3, 3, 64, 128), dtype=tf.float32, name=None)
#   134054367340368: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   134054367338256: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   134054367338448: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   134054367343056: TensorSpec(shape=(1, 1, 384, 256), dtype=tf.float32, name=None)
#   134054367342288: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   134054367340944: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   134054367342672: TensorSpec(shape=(3, 3, 256, 256), dtype=tf.float32, name=None)
#   134054367341328: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   134054367343440: TensorSpec(shape=(1, 1, 768, 512), dtype=tf.float32, name=None)
#   134054367340176: TensorSpec(shape=(512,), dtype=tf.float32, name=None)
#   134054367343632: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   134054367344400: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   134054367345552: TensorSpec(shape=(1, 1, 256, 128), dtype=tf.float32, name=None)
#   134054367344592: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   134054367346128: TensorSpec(shape=(3, 3, 128, 128), dtype=tf.float32, name=None)
#   134054091440784: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   134054091441936: TensorSpec(shape=(3, 3, 128, 128), dtype=tf.float32, name=None)
#   134054091441552: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   134054091442896: TensorSpec(shape=(3, 3, 128, 128), dtype=tf.float32, name=None)
#   134054091440976: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   134054091442128: TensorSpec(shape=(3, 3, 128, 128), dtype=tf.float32, name=None)
#   134054367344784: TensorSpec(shape=(1, 1, 256, 128), dtype=tf.float32, name=None)
#   134054091442704: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   134054367345744: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   134054091442320: TensorSpec(shape=(1, 1, 256, 256), dtype=tf.float32, name=None)
#   134054091443088: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   134054367344976: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   134054367345168: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   134054091443664: TensorSpec(shape=(1, 1, 768, 512), dtype=tf.float32, name=None)
#   134054091443472: TensorSpec(shape=(512,), dtype=tf.float32, name=None)
#   134054091443280: TensorSpec(shape=(3, 3, 512, 1), dtype=tf.float32, name=None)
#   134054367342096: TensorSpec(shape=(3, 3, 256, 1), dtype=tf.float32, name=None)
#   134054367335376: TensorSpec(shape=(3, 3, 128, 1), dtype=tf.float32, name=None)
#   134054091443856: TensorSpec(shape=(512,), dtype=tf.float32, name=None)
#   134054367341712: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   134054367335568: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   134054091444624: TensorSpec(shape=(1, 1, 512, 128), dtype=tf.float32, name=None)
#   134054367342480: TensorSpec(shape=(1, 1, 256, 128), dtype=tf.float32, name=None)
#   134054367336336: TensorSpec(shape=(1, 1, 128, 128), dtype=tf.float32, name=None)
#   134054091442512: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   134054367341520: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   134054367333648: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   134054091444240: TensorSpec(shape=(3, 3, 128, 1), dtype=tf.float32, name=None)
#   134054091441360: TensorSpec(shape=(3, 3, 512, 64), dtype=tf.float32, name=None)
#   134054367344016: TensorSpec(shape=(3, 3, 128, 1), dtype=tf.float32, name=None)
#   134054367342864: TensorSpec(shape=(3, 3, 256, 64), dtype=tf.float32, name=None)
#   134054367337296: TensorSpec(shape=(3, 3, 128, 1), dtype=tf.float32, name=None)
#   134054367335184: TensorSpec(shape=(3, 3, 128, 64), dtype=tf.float32, name=None)
#   134054091445392: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   134054091441744: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   134054367344208: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   134054367341904: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   134054367337488: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   134054367334992: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   134054091445776: TensorSpec(shape=(1, 1, 128, 128), dtype=tf.float32, name=None)
#   134054091444048: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   134054367346320: TensorSpec(shape=(1, 1, 128, 128), dtype=tf.float32, name=None)
#   134054367339600: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   134054367338064: TensorSpec(shape=(1, 1, 128, 128), dtype=tf.float32, name=None)
#   134054367335952: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   134054091445008: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   134054091444432: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   134054367346512: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   134054367341136: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   134054367339024: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   134054367335760: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   134054091445968: TensorSpec(shape=(1, 1, 128, 80), dtype=tf.float32, name=None)
#   134054091444816: TensorSpec(shape=(1, 1, 64, 64), dtype=tf.float32, name=None)
#   134054091441168: TensorSpec(shape=(1, 1, 128, 80), dtype=tf.float32, name=None)
#   134054367343824: TensorSpec(shape=(1, 1, 64, 64), dtype=tf.float32, name=None)
#   134054367340752: TensorSpec(shape=(1, 1, 128, 80), dtype=tf.float32, name=None)
#   134054367337104: TensorSpec(shape=(1, 1, 64, 64), dtype=tf.float32, name=None)
#   134054091445200: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   134054091446160: TensorSpec(shape=(80,), dtype=tf.float32, name=None)
#   134054367343248: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   134054091440592: TensorSpec(shape=(80,), dtype=tf.float32, name=None)
#   134054367336528: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   134054367340560: TensorSpec(shape=(80,), dtype=tf.float32, name=None)
#   134054091448464: TensorSpec(shape=(3,), dtype=tf.int64, name=None)
#   134054091445584: TensorSpec(shape=(3,), dtype=tf.int64, name=None)
#   134054091450000: TensorSpec(shape=(1, 1, 16, 1), dtype=tf.float32, name=None)
#   134054091446544: TensorSpec(shape=(3,), dtype=tf.int64, name=None)
#   134054091450768: TensorSpec(shape=(3,), dtype=tf.int64, name=None)
#   134054091449040: TensorSpec(shape=(3,), dtype=tf.int64, name=None)
#   134054091449616: TensorSpec(shape=(3,), dtype=tf.int64, name=None)
#   134054091449232: TensorSpec(shape=(1, 2, 8400), dtype=tf.float32, name=None)
#   134054091449808: TensorSpec(shape=(1, 2, 8400), dtype=tf.float32, name=None)
#   134054091446928: TensorSpec(shape=(3,), dtype=tf.int64, name=None)
#   134054091447120: TensorSpec(shape=(3,), dtype=tf.int64, name=None)
# TensorFlow SavedModel: export success ✅ 43.2s, saved as 'yolo11s_saved_model' (91.0 MB)
#
# TensorFlow Lite: starting export with tensorflow 2.19.0...
# TensorFlow Lite: export success ✅ 0.0s, saved as 'yolo11s_saved_model/yolo11s_float32.tflite' (36.3 MB)
#
# Export complete (44.1s)
# Results saved to /content
# Predict:         yolo predict task=detect model=yolo11s_saved_model/yolo11s_float32.tflite imgsz=640
# Validate:        yolo val task=detect model=yolo11s_saved_model/yolo11s_float32.tflite imgsz=640 data=/usr/src/ultralytics/ultralytics/cfg/datasets/coco.yaml
# Visualize:       https://netron.app
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-4139936526.py in <cell line: 0>()
#      13 # ✅ Optional: List exported files
#      14 import os
# ---> 15 for file in os.listdir("runs/export"):
#      16     print("Exported:", file)
#      17
#
# FileNotFoundError: [Errno 2] No such file or directory: 'runs/export'
